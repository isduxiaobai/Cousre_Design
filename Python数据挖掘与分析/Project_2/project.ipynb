# %%
import time
print(time.ctime())
# Out:
# Fri Dec  3 08:26:14 2021

# %%
# !pip install --upgrade pyecharts
# Out:
# Collecting pyecharts
#   Downloading pyecharts-1.9.1-py3-none-any.whl (135 kB)
#      |████████████████████████████████| 135 kB 643 kB/s eta 0:00:01
# Requirement already satisfied: jinja2 in /Users/duxiaobai/opt/anaconda3/lib/python3.8/site-packages (from pyecharts) (2.11.3)
# Collecting prettytable
#   Using cached prettytable-2.4.0-py3-none-any.whl (24 kB)
# Collecting simplejson
#   Downloading simplejson-3.17.6-cp38-cp38-macosx_10_9_x86_64.whl (74 kB)
#      |████████████████████████████████| 74 kB 503 kB/s eta 0:00:01
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/duxiaobai/opt/anaconda3/lib/python3.8/site-packages (from jinja2->pyecharts) (1.1.1)
# Requirement already satisfied: wcwidth in /Users/duxiaobai/opt/anaconda3/lib/python3.8/site-packages (from prettytable->pyecharts) (0.2.5)
# Installing collected packages: simplejson, prettytable, pyecharts
# Successfully installed prettytable-2.4.0 pyecharts-1.9.1 simplejson-3.17.6

# %%
# !pip install -i https://mirrors.aliyun.com/pypi/simple/ jieba
# Out:
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# Collecting jieba
#   Downloading https://mirrors.aliyun.com/pypi/packages/c6/cb/18eeb235f833b726522d7ebed54f2278ce28ba9438e3135ab0278d9792a2/jieba-0.42.1.tar.gz (19.2 MB)
#      |████████████████████████████████| 19.2 MB 98 kB/s eta 0:00:012     |█████████████████████▌          | 12.9 MB 158 kB/s eta 0:00:40     |████████████████████████▌       | 14.7 MB 48 kB/s eta 0:01:34     |███████████████████████████▉    | 16.7 MB 23 kB/s eta 0:01:48     |████████████████████████████    | 16.8 MB 43 kB/s eta 0:00:56
# Building wheels for collected packages: jieba
# done
#   Created wheel for jieba: filename=jieba-0.42.1-py3-none-any.whl size=19314477 sha256=d3906d0fcf7a785cbb6693a0a2fcd113f754086c5543ce24e52a9812c523b9ad
#   Stored in directory: /Users/duxiaobai/Library/Caches/pip/wheels/44/66/13/57d80ae29d31d0ed7ee6898cb75a5c3c6da353e5e1ef5a6203
# Successfully built jieba
# Installing collected packages: jieba
# Successfully installed jieba-0.42.1

# %%
# !pip install -i https://mirrors.aliyun.com/pypi/simple/ pandas
# Out:
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# Collecting pandas
#   Downloading https://mirrors.aliyun.com/pypi/packages/56/dd/9676967eac629273b2da40c53845f28d58af1800940d9b4067fc9a735dfb/pandas-1.3.4-cp38-cp38-macosx_10_9_x86_64.whl (11.4 MB)
#      |████████████████████████████████| 11.4 MB 239 kB/s eta 0:00:01    |███████████████▊                | 5.6 MB 277 kB/s eta 0:00:21
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/duxiaobai/opt/anaconda3/lib/python3.8/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /Users/duxiaobai/opt/anaconda3/lib/python3.8/site-packages (from pandas) (2021.1)
# Collecting numpy>=1.17.3
#   Downloading https://mirrors.aliyun.com/pypi/packages/97/95/c3b2b3e5fcc641edf4711ff41797811b825899c52e673fc9364372c1d3e6/numpy-1.21.4-cp38-cp38-macosx_10_9_x86_64.whl (16.9 MB)
#      |████████████████████████████████| 16.9 MB 59 kB/s eta 0:00:014    |████▌                           | 2.4 MB 238 kB/s eta 0:01:02
# Requirement already satisfied: six>=1.5 in /Users/duxiaobai/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Installing collected packages: numpy, pandas
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# moviepy 1.0.3 requires imageio<3.0,>=2.5; python_version >= "3.4", which is not installed.
# moviepy 1.0.3 requires decorator<5.0,>=4.0.2, but you have decorator 5.0.6 which is incompatible.
# Successfully installed numpy-1.21.4 pandas-1.3.4

# %%
import jieba
import pandas as pd
from collections import Counter
from pyecharts.charts import Line,Pie,Scatter,Bar,Map,Grid
from pyecharts.charts import WordCloud
from pyecharts import options as opts
from pyecharts.globals import ThemeType
from pyecharts.globals import SymbolType
from pyecharts.commons.utils import JsCode

# %%
# 2.Pandas数据处理

# %%
# 2.1读取数据
df = pd.read_excel('././data/旅游景点.xlsx')
df.head()
print("读取完毕")
# Out:
# 读取完毕

# %%
# 2.2 查看索引、数据类型和内存信息
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2443 entries, 0 to 2442
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   城市      2443 non-null   object
#  1   名称      2443 non-null   object
#  2   星级      913 non-null    object
#  3   评分      2443 non-null   float64
#  4   价格      2443 non-null   float64
#  5   销量      2443 non-null   int64
#  6   省/市/区   2443 non-null   object
#  7   坐标      2443 non-null   object
#  8   简介      2402 non-null   object
#  9   是否免费    2443 non-null   bool
#  10  具体地址    2440 non-null   object
# dtypes: bool(1), float64(2), int64(1), object(7)
# memory usage: 193.4+ KB

# %%
# 2.3 查看数值型列汇总统计
df.describe()
# Out:
#                 评分            价格            销量
# count  2443.000000   2443.000000   2443.000000
# mean      1.683135    151.780929    360.652886
# std       2.012527    649.170226   1043.798441
# min       0.000000      0.000000      0.000000
# 25%       0.000000     32.000000     40.000000
# 50%       0.000000     62.000000     90.000000
# 75%       3.700000    120.000000    270.000000
# max       5.000000  23888.000000  19459.000000

# %%
# 2.4 查看销量为0的行
df.loc[df['销量']==0,:].head()
# Out:
#      城市      名称   星级   评分   价格  销量  省/市/区                               坐标  \
# 301  台湾  复兴桥风景区  NaN  0.0  0.0   0  台湾·桃园  121.35037883956,24.815040245504
# 302  台湾     长春祠  NaN  3.5  0.0   0  台湾·花莲  121.60445032684,24.162302549393
# 303  台湾    淡水老街  NaN  0.0  0.0   0  台湾·淡水  121.44124069779,25.171297755773
# 304  台湾    士林官邸  NaN  5.0  0.0   0  台湾·台北  121.53013540214,25.093934468272
# 305  台湾    北安公园  NaN  5.0  0.0   0  台湾·台北  121.52694244942,25.076889096728
#
#                      简介   是否免费               具体地址
# 301   带动了北横碧水青山的另一种欢乐风情  False       桃园县复兴乡中正路15号
# 302     一道飞瀑分流入溪，山水景色绝佳   True              台湾花莲县
# 303        美食汇聚的北台湾老街之一   True          台北县淡水镇中正路
# 304    林木参天、绿树幽深，极富神秘色彩   True  台北市士林区中山北路五段兴福林路口
# 305  满园新绿，温雅如诗，连绵一片绿意盎然  False    台湾台北市中山北路四段北安路旁

# %%
# 2.5 去除销量为0的行数据
df = df[df['销量']!=0]
df.shape
# Out:
# (2320, 11)

# %%
# 2.6 统计各列空值
df.isnull().sum()
#星级存在1407个空值，简介37个空值，具体地址2个空值，其他列不存在空值，数据还算比较完整。
# Out:
# 城市          0
# 名称          0
# 星级       1407
# 评分          0
# 价格          0
# 销量          0
# 省/市/区       0
# 坐标          0
# 简介         37
# 是否免费        0
# 具体地址        2
# dtype: int64

# %%
# 2.7 将星级缺失值用‘未知’填充
df['星级'].fillna('未知', inplace=True)
df.isnull().sum()
# Out:
# 城市        0
# 名称        0
# 星级        0
# 评分        0
# 价格        0
# 销量        0
# 省/市/区     0
# 坐标        0
# 简介       37
# 是否免费      0
# 具体地址      2
# dtype: int64

# %%
# 2.8 也可以将所有缺失值都用‘未知’填充
df.fillna('未知', inplace=True)
df.isnull().sum()
# Out:
# 城市       0
# 名称       0
# 星级       0
# 评分       0
# 价格       0
# 销量       0
# 省/市/区    0
# 坐标       0
# 简介       0
# 是否免费     0
# 具体地址     0
# dtype: int64

# %%
# 2.9 按销量排序
df.sort_values('销量', ascending=False).head()
# Out:
#       城市             名称  星级   评分     价格     销量       省/市/区  \
# 0     上海        上海迪士尼乐园  未知  0.0  325.0  19459  上海·上海·浦东新区
# 1     上海       上海海昌海洋公园  4A  0.0  276.5  19406  上海·上海·浦东新区
# 211   北京             故宫  5A  5.0   58.6  15277   北京·北京·东城区
# 2187  陕西  秦始皇帝陵博物院（兵马俑）  5A  4.4  120.0  12714   陕西·西安·临潼区
# 474   四川    成都大熊猫繁育研究基地  4A  4.0   52.0   9731   四川·成都·成华区
#
#                         坐标                    简介   是否免费  \
# 0     121.667917,31.149712          每个女孩都有一场迪士尼梦  False
# 1     121.915647,30.917713    看珍稀海洋生物 | 玩超刺激娱乐项目  False
# 211   116.403347,39.922148      世界五大宫之首，穿越与您近在咫尺  False
# 2187  109.266029,34.386024               世界第八大奇迹  False
# 474   104.152603,30.738951  无关黑与白， 不分胖与瘦， 可爱而又温暖  False
#
#                           具体地址
# 0     上海市浦东新区川沙镇黄赵路310号上海迪士尼乐园
# 1            上海市浦东新区南汇城银飞路166号
# 211               北京市东城区景山前街4号
# 2187      陕西省西安市临潼县秦始皇陵东1.5公里处
# 474       四川省成都市成华区外北熊猫大道1375号

# %%
## 3. Pyecharts数据可视化

# %%
# 3.1 销量前20热门景点数据
# 线性渐变
color_js = """new echarts.graphic.LinearGradient(0, 0, 1, 0,
    [{offset: 0, color: '#009ad6'}, {offset: 1, color: '#ed1941'}], false)"""


sort_info = df.sort_values(by='销量', ascending=True)
b1 = (
    Bar()
    .add_xaxis(list(sort_info['名称'])[-20:])
    .add_yaxis('热门景点销量', sort_info['销量'].values.tolist()[-20:],itemstyle_opts=opts.ItemStyleOpts(color=JsCode(color_js)))
    .reversal_axis()
    .set_global_opts(
        title_opts=opts.TitleOpts(title='热门景点销量数据'),
        yaxis_opts=opts.AxisOpts(name='景点名称'),
        xaxis_opts=opts.AxisOpts(name='销量'),
        )
    .set_series_opts(label_opts=opts.LabelOpts(position="right"))

)
# 将图形整体右移
g1 = (
    Grid()
        .add(b1, grid_opts=opts.GridOpts(pos_left='20%', pos_right='5%'))
)
g1.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="6ed1735397d04031a9df8e15a60ac878" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_6ed1735397d04031a9df8e15a60ac878 = echarts.init(
#                     document.getElementById('6ed1735397d04031a9df8e15a60ac878'), 'white', {renderer: 'canvas'});
#                 var option_6ed1735397d04031a9df8e15a60ac878 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u70ed\u95e8\u666f\u70b9\u9500\u91cf",
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "legendHoverLink": true,
#             "data": [
#                 5195,
#                 5260,
#                 5300,
#                 5353,
#                 5498,
#                 5702,
#                 5808,
#                 5920,
#                 6005,
#                 6468,
#                 6545,
#                 6764,
#                 8891,
#                 9618,
#                 9633,
#                 9731,
#                 12714,
#                 15277,
#                 19406,
#                 19459
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             },
#             "itemStyle": {
#                 "color": new echarts.graphic.LinearGradient(0, 0, 1, 0,    [{offset: 0, color: '#009ad6'}, {offset: 1, color: '#ed1941'}], false)
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u70ed\u95e8\u666f\u70b9\u9500\u91cf"
#             ],
#             "selected": {
#                 "\u70ed\u95e8\u666f\u70b9\u9500\u91cf": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "name": "\u9500\u91cf",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "name": "\u666f\u70b9\u540d\u79f0",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u957f\u6068\u6b4c",
#                 "\u606d\u738b\u5e9c",
#                 "\u5929\u575b\u516c\u56ed",
#                 "\u4e1c\u65b9\u7eff\u821f",
#                 "\u5317\u4eac\u91ce\u751f\u52a8\u7269\u56ed",
#                 "\u534e\u6e05\u5bab",
#                 "\u534e\u5c71\u666f\u533a",
#                 "\u5357\u4eac\u603b\u7edf\u5e9c",
#                 "\u7626\u897f\u6e56",
#                 "\u4e03\u5f69\u4e91\u5357\u6b22\u4e50\u4e16\u754c",
#                 "\u73e0\u6d77\u957f\u9686\u6d77\u6d0b\u738b\u56fd",
#                 "\u4e0a\u6d77\u91ce\u751f\u52a8\u7269\u56ed",
#                 "\u957f\u9686\u91ce\u751f\u52a8\u7269\u4e16\u754c",
#                 "\u516b\u8fbe\u5cad\u957f\u57ce",
#                 "\u9890\u548c\u56ed",
#                 "\u6210\u90fd\u5927\u718a\u732b\u7e41\u80b2\u7814\u7a76\u57fa\u5730",
#                 "\u79e6\u59cb\u7687\u5e1d\u9675\u535a\u7269\u9662\uff08\u5175\u9a6c\u4fd1\uff09",
#                 "\u6545\u5bab",
#                 "\u4e0a\u6d77\u6d77\u660c\u6d77\u6d0b\u516c\u56ed",
#                 "\u4e0a\u6d77\u8fea\u58eb\u5c3c\u4e50\u56ed"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "text": "\u70ed\u95e8\u666f\u70b9\u9500\u91cf\u6570\u636e",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "grid": [
#         {
#             "show": false,
#             "zlevel": 0,
#             "z": 2,
#             "left": "20%",
#             "right": "5%",
#             "containLabel": false,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1
#         }
#     ]
# };
#                 chart_6ed1735397d04031a9df8e15a60ac878.setOption(option_6ed1735397d04031a9df8e15a60ac878);
#         });
#     </script>

# %%
# 3.2 假期出行数据全国地图分布
df_tmp1 = df[['城市','销量']]
df_counts = df_tmp1.groupby('城市').sum()
m1 = (
        Map()
        .add('假期出行分布', [list(z) for z in zip(df_counts.index.values.tolist(), df_counts.values.tolist())], 'china')
        .set_global_opts(
        title_opts=opts.TitleOpts(title='假期出行数据地图分布'),
        visualmap_opts=opts.VisualMapOpts(max_=100000, is_piecewise=False,range_color=["white", "#fa8072", "#ed1941"]),
        )
    )
m1.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="6938c5b4994448599f8dfb40eced8024" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_6938c5b4994448599f8dfb40eced8024 = echarts.init(
#                     document.getElementById('6938c5b4994448599f8dfb40eced8024'), 'white', {renderer: 'canvas'});
#                 var option_6938c5b4994448599f8dfb40eced8024 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u5047\u671f\u51fa\u884c\u5206\u5e03",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": [
#                         84084
#                     ]
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": [
#                         28056
#                     ]
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": [
#                         3959
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": [
#                         93987
#                     ]
#                 },
#                 {
#                     "name": "\u53f0\u6e7e",
#                     "value": [
#                         1001
#                     ]
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": [
#                         3772
#                     ]
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": [
#                         65052
#                     ]
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": [
#                         5254
#                     ]
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": [
#                         5622
#                     ]
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": [
#                         21027
#                     ]
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": [
#                         32147
#                     ]
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": [
#                         15904
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": [
#                         62757
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": [
#                         37946
#                     ]
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": [
#                         3614
#                     ]
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": [
#                         80783
#                     ]
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": [
#                         11046
#                     ]
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": [
#                         6826
#                     ]
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": [
#                         33776
#                     ]
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": [
#                         45481
#                     ]
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": [
#                         44123
#                     ]
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": [
#                         22563
#                     ]
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": [
#                         6980
#                     ]
#                 },
#                 {
#                     "name": "\u6fb3\u95e8",
#                     "value": [
#                         3128
#                     ]
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": [
#                         4338
#                     ]
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": [
#                         23256
#                     ]
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": [
#                         7028
#                     ]
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": [
#                         22499
#                     ]
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": [
#                         10423
#                     ]
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": [
#                         20054
#                     ]
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": [
#                         64353
#                     ]
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": [
#                         4591
#                     ]
#                 },
#                 {
#                     "name": "\u9999\u6e2f",
#                     "value": [
#                         1006
#                     ]
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": [
#                         4639
#                     ]
#                 }
#             ],
#             "roam": true,
#             "aspectScale": 0.75,
#             "nameProperty": "name",
#             "selectedMode": false,
#             "zoom": 1,
#             "mapValueCalculation": "sum",
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5047\u671f\u51fa\u884c\u5206\u5e03"
#             ],
#             "selected": {
#                 "\u5047\u671f\u51fa\u884c\u5206\u5e03": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",

# %%
# 3.3 各省市4A-5A景区数量柱状图
# 线性渐变
color_js = """new echarts.graphic.LinearGradient(0, 1, 0, 0,
    [{offset: 0, color: '#009ad6'}, {offset: 1, color: '#ed1941'}], false)"""

df_tmp2 = df[df['星级'].isin(['4A', '5A'])]
df_counts = df_tmp2.groupby('城市').count()['星级']
b2 = (
        Bar()
            .add_xaxis(df_counts.index.values.tolist())
            .add_yaxis('4A-5A景区数量', df_counts.values.tolist(),itemstyle_opts=opts.ItemStyleOpts(color=JsCode(color_js)))
            .set_global_opts(
            title_opts=opts.TitleOpts(title='各省市4A-5A景区数量'),
            datazoom_opts=[opts.DataZoomOpts(), opts.DataZoomOpts(type_='inside')],
        )
    )
b2.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="0dbeacf805e247b29a60fd79efd99da1" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_0dbeacf805e247b29a60fd79efd99da1 = echarts.init(
#                     document.getElementById('0dbeacf805e247b29a60fd79efd99da1'), 'white', {renderer: 'canvas'});
#                 var option_0dbeacf805e247b29a60fd79efd99da1 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "4A-5A\u666f\u533a\u6570\u91cf",
#             "legendHoverLink": true,
#             "data": [
#                 25,
#                 31,
#                 23,
#                 38,
#                 10,
#                 32,
#                 18,
#                 18,
#                 47,
#                 30,
#                 36,
#                 33,
#                 27,
#                 15,
#                 47,
#                 34,
#                 36,
#                 39,
#                 29,
#                 24,
#                 37,
#                 14,
#                 19,
#                 19,
#                 7,
#                 18,
#                 23,
#                 33,
#                 31,
#                 18,
#                 17
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "itemStyle": {
#                 "color": new echarts.graphic.LinearGradient(0, 1, 0, 0,    [{offset: 0, color: '#009ad6'}, {offset: 1, color: '#ed1941'}], false)
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "4A-5A\u666f\u533a\u6570\u91cf"
#             ],
#             "selected": {
#                 "4A-5A\u666f\u533a\u6570\u91cf": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u4e0a\u6d77",
#                 "\u4e91\u5357",
#                 "\u5185\u8499\u53e4",
#                 "\u5317\u4eac",
#                 "\u5409\u6797",
#                 "\u56db\u5ddd",
#                 "\u5929\u6d25",
#                 "\u5b81\u590f",
#                 "\u5b89\u5fbd",
#                 "\u5c71\u4e1c",
#                 "\u5c71\u897f",
#                 "\u5e7f\u4e1c",
#                 "\u5e7f\u897f",
#                 "\u65b0\u7586",
#                 "\u6c5f\u82cf",
#                 "\u6c5f\u897f",
#                 "\u6cb3\u5317",
#                 "\u6cb3\u5357",
#                 "\u6d59\u6c5f",
#                 "\u6d77\u5357",
#                 "\u6e56\u5317",
#                 "\u6e56\u5357",
#                 "\u7518\u8083",
#                 "\u798f\u5efa",
#                 "\u897f\u85cf",
#                 "\u8d35\u5dde",
#                 "\u8fbd\u5b81",
#                 "\u91cd\u5e86",
#                 "\u9655\u897f",
#                 "\u9752\u6d77",
#                 "\u9ed1\u9f99\u6c5f"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u5404\u7701\u5e024A-5A\u666f\u533a\u6570\u91cf",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "dataZoom": [
#         {
#             "show": true,
#             "type": "slider",
#             "realtime": true,
#             "start": 20,
#             "end": 80,
#             "orient": "horizontal",
#             "zoomLock": false,
#             "filterMode": "filter"
#         },
#         {
#             "show": true,
#             "type": "inside",
#             "realtime": true,
#             "start": 20,
#             "end": 80,
#             "orient": "horizontal",
#             "zoomLock": false,
#             "filterMode": "filter"
#         }
#     ]
# };
#                 chart_0dbeacf805e247b29a60fd79efd99da1.setOption(option_0dbeacf805e247b29a60fd79efd99da1);
#         });
#     </script>

# %%
# 3.4 各省市4A-5A景区数量玫瑰图
df0 = df_counts.copy()
df0.sort_values(ascending=False, inplace=True)
c1 = (
    Pie()
    .add('', [list(z) for z in zip(df0.index.values.tolist(), df0.values.tolist())],
         radius=['30%', '100%'],
         center=['50%', '60%'],
         rosetype='area',
         )
    .set_global_opts(title_opts=opts.TitleOpts(title='地区景点数量'),
                     legend_opts=opts.LegendOpts(is_show=False),
                     toolbox_opts=opts.ToolboxOpts())
    .set_series_opts(label_opts=opts.LabelOpts(is_show=True, position='inside', font_size=12,
                                               formatter='{b}: {c}', font_style='italic',
                                               font_weight='bold', font_family='Microsoft YaHei'
                                               ))
)
c1.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="a00350fc6ed542e584bf391e0ebbc07f" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_a00350fc6ed542e584bf391e0ebbc07f = echarts.init(
#                     document.getElementById('a00350fc6ed542e584bf391e0ebbc07f'), 'white', {renderer: 'canvas'});
#                 var option_a00350fc6ed542e584bf391e0ebbc07f = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 47
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 47
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 39
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 38
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 37
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 36
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 36
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 34
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 33
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 33
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 32
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 31
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 31
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 30
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 29
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 27
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 25
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 24
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 23
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 23
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 19
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 19
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 18
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 18
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 18
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 18
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 17
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 15
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 14
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 10
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 7
#                 }
#             ],
#             "radius": [
#                 "30%",
#                 "100%"
#             ],
#             "center": [
#                 "50%",
#                 "60%"
#             ],
#             "roseType": "area",
#             "label": {
#                 "show": true,
#                 "position": "inside",
#                 "margin": 8,
#                 "fontSize": 12,
#                 "fontStyle": "italic",
#                 "fontWeight": "bold",
#                 "fontFamily": "Microsoft YaHei",
#                 "formatter": "{b}: {c}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5b89\u5fbd",
#                 "\u6c5f\u82cf",
#                 "\u6cb3\u5357",
#                 "\u5317\u4eac",
#                 "\u6e56\u5317",
#                 "\u6cb3\u5317",
#                 "\u5c71\u897f",
#                 "\u6c5f\u897f",
#                 "\u91cd\u5e86",
#                 "\u5e7f\u4e1c",
#                 "\u56db\u5ddd",
#                 "\u9655\u897f",
#                 "\u4e91\u5357",
#                 "\u5c71\u4e1c",
#                 "\u6d59\u6c5f",
#                 "\u5e7f\u897f",
#                 "\u4e0a\u6d77",
#                 "\u6d77\u5357",
#                 "\u8fbd\u5b81",
#                 "\u5185\u8499\u53e4",
#                 "\u7518\u8083",
#                 "\u798f\u5efa",
#                 "\u5b81\u590f",
#                 "\u5929\u6d25",
#                 "\u8d35\u5dde",
#                 "\u9752\u6d77",
#                 "\u9ed1\u9f99\u6c5f",
#                 "\u65b0\u7586",
#                 "\u6e56\u5357",
#                 "\u5409\u6797",
#                 "\u897f\u85cf"
#             ],
#             "selected": {},
#             "show": false,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "\u5730\u533a\u666f\u70b9\u6570\u91cf",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "horizontal",
#         "itemSize": 15,
#         "itemGap": 10,
#         "left": "80%",
#         "feature": {
#             "saveAsImage": {
#                 "type": "png",
#                 "backgroundColor": "auto",
#                 "connectedBackgroundColor": "#fff",
#                 "show": true,
#                 "title": "\u4fdd\u5b58\u4e3a\u56fe\u7247",
#                 "pixelRatio": 1
#             },
#             "restore": {
#                 "show": true,
#                 "title": "\u8fd8\u539f"

# %%
# 3.5 各省市4A-5A景区数量阴影散点图
item_style = {'normal': {'shadowColor': '#000000',
                         'shadowBlur': 20,
                         'shadowOffsetX':5,
                         'shadowOffsetY':15
                         }
              }
s1 = (
        Scatter()
        .add_xaxis(df_counts.index.values.tolist())
        .add_yaxis('4A-5A景区数量', df_counts.values.tolist(),symbol_size=50,itemstyle_opts=item_style)
        .set_global_opts(visualmap_opts=opts.VisualMapOpts(is_show=False,
                                              type_='size',
                                              range_size=[5,50]))
)
s1.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="acf14c1288fd4fd0b4498b83f2c50beb" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_acf14c1288fd4fd0b4498b83f2c50beb = echarts.init(
#                     document.getElementById('acf14c1288fd4fd0b4498b83f2c50beb'), 'white', {renderer: 'canvas'});
#                 var option_acf14c1288fd4fd0b4498b83f2c50beb = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "name": "4A-5A\u666f\u533a\u6570\u91cf",
#             "symbolSize": 50,
#             "data": [
#                 [
#                     "\u4e0a\u6d77",
#                     25
#                 ],
#                 [
#                     "\u4e91\u5357",
#                     31
#                 ],
#                 [
#                     "\u5185\u8499\u53e4",
#                     23
#                 ],
#                 [
#                     "\u5317\u4eac",
#                     38
#                 ],
#                 [
#                     "\u5409\u6797",
#                     10
#                 ],
#                 [
#                     "\u56db\u5ddd",
#                     32
#                 ],
#                 [
#                     "\u5929\u6d25",
#                     18
#                 ],
#                 [
#                     "\u5b81\u590f",
#                     18
#                 ],
#                 [
#                     "\u5b89\u5fbd",
#                     47
#                 ],
#                 [
#                     "\u5c71\u4e1c",
#                     30
#                 ],
#                 [
#                     "\u5c71\u897f",
#                     36
#                 ],
#                 [
#                     "\u5e7f\u4e1c",
#                     33
#                 ],
#                 [
#                     "\u5e7f\u897f",
#                     27
#                 ],
#                 [
#                     "\u65b0\u7586",
#                     15
#                 ],
#                 [
#                     "\u6c5f\u82cf",
#                     47
#                 ],
#                 [
#                     "\u6c5f\u897f",
#                     34
#                 ],
#                 [
#                     "\u6cb3\u5317",
#                     36
#                 ],
#                 [
#                     "\u6cb3\u5357",
#                     39
#                 ],
#                 [
#                     "\u6d59\u6c5f",
#                     29
#                 ],
#                 [
#                     "\u6d77\u5357",
#                     24
#                 ],
#                 [
#                     "\u6e56\u5317",
#                     37
#                 ],
#                 [
#                     "\u6e56\u5357",
#                     14
#                 ],
#                 [
#                     "\u7518\u8083",
#                     19
#                 ],
#                 [
#                     "\u798f\u5efa",
#                     19
#                 ],
#                 [
#                     "\u897f\u85cf",
#                     7
#                 ],
#                 [
#                     "\u8d35\u5dde",
#                     18
#                 ],
#                 [
#                     "\u8fbd\u5b81",
#                     23
#                 ],
#                 [
#                     "\u91cd\u5e86",
#                     33
#                 ],
#                 [
#                     "\u9655\u897f",
#                     31
#                 ],
#                 [
#                     "\u9752\u6d77",
#                     18
#                 ],
#                 [
#                     "\u9ed1\u9f99\u6c5f",
#                     17
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             },
#             "itemStyle": {
#                 "normal": {
#                     "shadowColor": "#000000",
#                     "shadowBlur": 20,
#                     "shadowOffsetX": 5,
#                     "shadowOffsetY": 15
#                 }
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "4A-5A\u666f\u533a\u6570\u91cf"
#             ],
#             "selected": {
#                 "4A-5A\u666f\u533a\u6570\u91cf": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u4e0a\u6d77",
#                 "\u4e91\u5357",
#                 "\u5185\u8499\u53e4",
#                 "\u5317\u4eac",
#                 "\u5409\u6797",
#                 "\u56db\u5ddd",
#                 "\u5929\u6d25",
#                 "\u5b81\u590f",
#                 "\u5b89\u5fbd",
#                 "\u5c71\u4e1c",
#                 "\u5c71\u897f",
#                 "\u5e7f\u4e1c",
#                 "\u5e7f\u897f",
#                 "\u65b0\u7586",
#                 "\u6c5f\u82cf",
#                 "\u6c5f\u897f",
#                 "\u6cb3\u5317",
#                 "\u6cb3\u5357",
#                 "\u6d59\u6c5f",
#                 "\u6d77\u5357",
#                 "\u6e56\u5317",
#                 "\u6e56\u5357",
#                 "\u7518\u8083",
#                 "\u798f\u5efa",
#                 "\u897f\u85cf",
#                 "\u8d35\u5dde",
#                 "\u8fbd\u5b81",
#                 "\u91cd\u5e86",
#                 "\u9655\u897f",
#                 "\u9752\u6d77",
#                 "\u9ed1\u9f99\u6c5f"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": false,
#         "type": "continuous",

# %%
# 3.6 各省市4A-5A景区地图分布
df_tmp3 = df[df['星级'].isin(['4A', '5A'])]
df_counts = df_tmp3.groupby('城市').count()['星级']
m2 = (
    Map()
    .add('4A-5A景区分布', [list(z) for z in zip(df_counts.index.values.tolist(), df_counts.values.tolist())], 'china')
    .set_global_opts(
    title_opts=opts.TitleOpts(title='地图数据分布'),
    visualmap_opts=opts.VisualMapOpts(max_=50, is_piecewise=True),
    )
)
m2.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="3e79a8d7a7bf49daadcf53ce4d3d3b50" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_3e79a8d7a7bf49daadcf53ce4d3d3b50 = echarts.init(
#                     document.getElementById('3e79a8d7a7bf49daadcf53ce4d3d3b50'), 'white', {renderer: 'canvas'});
#                 var option_3e79a8d7a7bf49daadcf53ce4d3d3b50 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "4A-5A\u666f\u533a\u5206\u5e03",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 25
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 31
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 23
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 38
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 10
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 32
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 18
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 18
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 47
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 30
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 36
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 33
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 27
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 15
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 47
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 34
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 36
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 39
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 29
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 24
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 37
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 14
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 19
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 19
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 7
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 18
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 23
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 33
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 31
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 18
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 17
#                 }
#             ],
#             "roam": true,
#             "aspectScale": 0.75,
#             "nameProperty": "name",
#             "selectedMode": false,
#             "zoom": 1,
#             "mapValueCalculation": "sum",
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "4A-5A\u666f\u533a\u5206\u5e03"
#             ],
#             "selected": {
#                 "4A-5A\u666f\u533a\u5206\u5e03": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "\u5730\u56fe\u6570\u636e\u5206\u5e03",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "piecewise",
#         "min": 0,
#         "max": 50,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 14,
#         "borderWidth": 0
#     }
# };
#                 chart_3e79a8d7a7bf49daadcf53ce4d3d3b50.setOption(option_3e79a8d7a7bf49daadcf53ce4d3d3b50);
#         });
#     </script>

# %%
# 3.7 门票价格区间占比玫瑰图
# 门票价格占比
price_level = [0, 50, 100, 150, 200, 250, 300, 350, 400, 500]
label_level = ['0-50', '50-100', '100-150', '150-200', '200-250', '250-300', '300-350', '350-400', '400-500']
jzmj_cut = pd.cut(df['价格'], price_level, labels=label_level)
df_price = jzmj_cut.value_counts()
df_price
# Out:
# 0-50       888
# 50-100     725
# 100-150    278
# 150-200    184
# 200-250     62
# 250-300     59
# 300-350     20
# 350-400     19
# 400-500     13
# Name: 价格, dtype: int64

# %%
p1 = (
    Pie(init_opts=opts.InitOpts(
            width='800px', height='600px',
            )
       )
        .add(
        '',
        [list(z) for z in zip(df_price.index.tolist(), df_price.values.tolist())],
        radius=['20%', '60%'],
        center=['40%', '50%'],
        rosetype='radius',
        label_opts=opts.LabelOpts(is_show=True),
        )
        .set_global_opts(title_opts=opts.TitleOpts(title='门票价格占比',pos_left='33%',pos_top="5%"),
                        legend_opts=opts.LegendOpts(type_='scroll', pos_left="80%",pos_top="25%",orient="vertical")
                        )
        .set_series_opts(label_opts=opts.LabelOpts(formatter='{b}: {c} ({d}%)'),position='outside')
    )
p1.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="fd394ecb00cb4bc49279f4c99a706791" style="width:800px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_fd394ecb00cb4bc49279f4c99a706791 = echarts.init(
#                     document.getElementById('fd394ecb00cb4bc49279f4c99a706791'), 'white', {renderer: 'canvas'});
#                 var option_fd394ecb00cb4bc49279f4c99a706791 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "0-50",
#                     "value": 888
#                 },
#                 {
#                     "name": "50-100",
#                     "value": 725
#                 },
#                 {
#                     "name": "100-150",
#                     "value": 278
#                 },
#                 {
#                     "name": "150-200",
#                     "value": 184
#                 },
#                 {
#                     "name": "200-250",
#                     "value": 62
#                 },
#                 {
#                     "name": "250-300",
#                     "value": 59
#                 },
#                 {
#                     "name": "300-350",
#                     "value": 20
#                 },
#                 {
#                     "name": "350-400",
#                     "value": 19
#                 },
#                 {
#                     "name": "400-500",
#                     "value": 13
#                 }
#             ],
#             "radius": [
#                 "20%",
#                 "60%"
#             ],
#             "center": [
#                 "40%",
#                 "50%"
#             ],
#             "roseType": "radius",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}: {c} ({d}%)"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             },
#             "position": "outside"
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "0-50",
#                 "50-100",
#                 "100-150",
#                 "150-200",
#                 "200-250",
#                 "250-300",
#                 "300-350",
#                 "350-400",
#                 "400-500"
#             ],
#             "selected": {},
#             "type": "scroll",
#             "show": true,
#             "left": "80%",
#             "top": "25%",
#             "orient": "vertical",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "\u95e8\u7968\u4ef7\u683c\u5360\u6bd4",
#             "left": "33%",
#             "top": "5%",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_fd394ecb00cb4bc49279f4c99a706791.setOption(option_fd394ecb00cb4bc49279f4c99a706791);
#         });
#     </script>

# %%
# 3.8 门票价格区间数量散点图
color_js = """new echarts.graphic.RadialGradient(
                    0.5, 0.5, 1,
                    [{offset: 0,
                      color: '#009ad6'},
                     {offset: 1,
                      color: '#ed1941'}
                      ])"""

s2 = (
        Scatter()
        .add_xaxis(df_price.index.tolist())
        .add_yaxis('门票价格区间', df_price.values.tolist(),symbol_size=50,itemstyle_opts=opts.ItemStyleOpts(color=JsCode(color_js)))
        .set_global_opts(
            yaxis_opts=opts.AxisOpts(name='数量'),
            xaxis_opts=opts.AxisOpts(name='价格区间(元)'))
        .set_global_opts(visualmap_opts=opts.VisualMapOpts(is_show=False,
                                              # 设置通过图形大小来表现数据
                                              type_='size',
                                              # 图形大小映射范围
                                              range_size=[5,50]))
)
s2.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="8c002a0ae3784a5991594a2667248126" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_8c002a0ae3784a5991594a2667248126 = echarts.init(
#                     document.getElementById('8c002a0ae3784a5991594a2667248126'), 'white', {renderer: 'canvas'});
#                 var option_8c002a0ae3784a5991594a2667248126 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "name": "\u95e8\u7968\u4ef7\u683c\u533a\u95f4",
#             "symbolSize": 50,
#             "data": [
#                 [
#                     "0-50",
#                     888
#                 ],
#                 [
#                     "50-100",
#                     725
#                 ],
#                 [
#                     "100-150",
#                     278
#                 ],
#                 [
#                     "150-200",
#                     184
#                 ],
#                 [
#                     "200-250",
#                     62
#                 ],
#                 [
#                     "250-300",
#                     59
#                 ],
#                 [
#                     "300-350",
#                     20
#                 ],
#                 [
#                     "350-400",
#                     19
#                 ],
#                 [
#                     "400-500",
#                     13
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             },
#             "itemStyle": {
#                 "color": new echarts.graphic.RadialGradient(                    0.5, 0.5, 1,                    [{offset: 0,                      color: '#009ad6'},                     {offset: 1,                      color: '#ed1941'}                      ])
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u95e8\u7968\u4ef7\u683c\u533a\u95f4"
#             ],
#             "selected": {
#                 "\u95e8\u7968\u4ef7\u683c\u533a\u95f4": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "name": "\u4ef7\u683c\u533a\u95f4(\u5143)",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "0-50",
#                 "50-100",
#                 "100-150",
#                 "150-200",
#                 "200-250",
#                 "250-300",
#                 "300-350",
#                 "350-400",
#                 "400-500"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "name": "\u6570\u91cf",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": false,
#         "type": "continuous",
#         "min": 0,
#         "max": 100,
#         "inRange": {
#             "symbolSize": [
#                 5,
#                 50
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     }
# };
#                 chart_8c002a0ae3784a5991594a2667248126.setOption(option_8c002a0ae3784a5991594a2667248126);
#         });
#     </script>

# %%
# 3.9 景点简介词云
contents = "".join('%s' % i for i in df['简介'].values.tolist())
contents_list = jieba.cut(contents)
ac = Counter(contents_list)

stopwords = []
with open('././data/stopwords.txt', "r",encoding='utf-8') as f:  # 打开文件
    data = f.read()  # 读取文件
    stopwords = data.split('\n')

for i in stopwords:
    del ac[i]

w1 = (
    WordCloud()
    .add("",
         ac.most_common(150),
         word_size_range=[5, 100],
         textstyle_opts=opts.TextStyleOpts(font_family="cursive"),
         shape='star')
    .set_global_opts(title_opts=opts.TitleOpts(title="景点简介词云"))
)
w1.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="ca432c4c7eae411ca20a6a819540cd31" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_ca432c4c7eae411ca20a6a819540cd31 = echarts.init(
#                     document.getElementById('ca432c4c7eae411ca20a6a819540cd31'), 'white', {renderer: 'canvas'});
#                 var option_ca432c4c7eae411ca20a6a819540cd31 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "star",
#             "rotationRange": [
#                 0,
#                 0
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 5,
#                 100
#             ],
#             "data": [
#                 {
#                     "name": "\u6587\u5316",
#                     "value": 151,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(140,145,141)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4f53\u9a8c",
#                     "value": 94,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(35,36,96)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e16\u754c",
#                     "value": 90,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(154,116,148)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6e29\u6cc9",
#                     "value": 88,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(76,37,0)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u65c5\u6e38",
#                     "value": 85,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(128,94,136)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e2d\u56fd",
#                     "value": 81,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(82,8,38)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u611f\u53d7",
#                     "value": 72,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(46,46,118)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4f11\u95f2",
#                     "value": 72,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(99,58,106)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\n",
#                     "value": 66,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(95,87,129)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e00\u4f53",
#                     "value": 66,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(24,54,132)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u666f\u533a",
#                     "value": 60,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(109,160,76)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5386\u53f2",
#                     "value": 60,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(149,158,96)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u96c6",
#                     "value": 55,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(86,37,155)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5927\u578b",
#                     "value": 53,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(100,20,155)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u81ea\u7136",
#                     "value": 50,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(78,11,2)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e50\u56ed",
#                     "value": 47,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(52,157,70)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e3b\u9898",
#                     "value": 47,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(144,121,77)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u52a8\u7269",
#                     "value": 45,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(52,103,43)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5efa\u7b51",
#                     "value": 44,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(115,153,81)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5ea6\u5047",
#                     "value": 41,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(55,157,5)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u72ec\u7279",
#                     "value": 40,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(5,117,107)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u98ce\u60c5",
#                     "value": 39,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(92,16,98)"
#                         }
#                     }

# %%
# 3.10 景点简介词云-自定义模板
w2 = (
    WordCloud()
    .add(
        "",
        ac.most_common(200),
        word_size_range=[5, 80],
        textstyle_opts=opts.TextStyleOpts(font_family="cursive"),
        mask_image='.//data/1.jpg'
    )
    .set_global_opts(
        title_opts=opts.TitleOpts(title="自定义样式词云图"),
    )
)
w2.render_notebook()
