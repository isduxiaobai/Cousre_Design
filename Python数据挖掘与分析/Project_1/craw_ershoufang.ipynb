# %%
# encoding:utf-8
# FileName: craw_lianjia_house
# Date:     2021/11
# Author:   xiaobai
# wechat:   zhiqiuxiaoyi
# Description: 爬取链接网的二手房信息
import os
import random
import re
import time
from collections import OrderedDict
from datetime import datetime

import pandas as pd
import requests
from bs4 import BeautifulSoup


def get_ua():
    """
    在UA库中随机选择一个UA
    :return: 返回一个库中的随机UA
    """
    ua_list = [
        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36 OPR/26.0.1656.60",
        "Opera/8.0 (Windows NT 5.1; U; en)",
        "Mozilla/5.0 (Windows NT 5.1; U; en; rv:1.8.1) Gecko/20061208 Firefox/2.0.0 Opera 9.50",
        "Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; en) Opera 9.50",
        "Mozilla/5.0 (Windows NT 6.1; WOW64; rv:34.0) Gecko/20100101 Firefox/34.0",
        "Mozilla/5.0 (X11; U; Linux x86_64; zh-CN; rv:1.9.2.10) Gecko/20100922 Ubuntu/10.10 (maverick) Firefox/3.6.10",
        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/534.57.2 (KHTML, like Gecko) Version/5.1.7 Safari/534.57.2",
        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.71 Safari/537.36",
        "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.11 (KHTML, like Gecko) Chrome/23.0.1271.64 Safari/537.11",
        "Mozilla/5.0 (Windows; U; Windows NT 6.1; en-US) AppleWebKit/534.16 (KHTML, like Gecko) Chrome/10.0.648.133 Safari/534.16",
        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/30.0.1599.101 Safari/537.36",
        "Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7.0; rv:11.0) like Gecko",
        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.11 (KHTML, like Gecko) Chrome/20.0.1132.11 TaoBrowser/2.0 Safari/536.11",
        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.1 (KHTML, like Gecko) Chrome/21.0.1180.71 Safari/537.1 LBBROWSER",
        "Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.1; WOW64; Trident/5.0; SLCC2; .NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729; Media Center PC 6.0; .NET4.0C; .NET4.0E; LBBROWSER)",
        "Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1; QQDownload 732; .NET4.0C; .NET4.0E; LBBROWSER)",
        "Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.1; WOW64; Trident/5.0; SLCC2; .NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729; Media Center PC 6.0; .NET4.0C; .NET4.0E; QQBrowser/7.0.3698.400)",
        "Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1; QQDownload 732; .NET4.0C; .NET4.0E)",
        "Mozilla/5.0 (Windows NT 5.1) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.84 Safari/535.11 SE 2.X MetaSr 1.0",
        "Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1; Trident/4.0; SV1; QQDownload 732; .NET4.0C; .NET4.0E; SE 2.X MetaSr 1.0)",
        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Maxthon/4.4.3.4000 Chrome/30.0.1599.101 Safari/537.36",
        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/38.0.2125.122 UBrowser/4.0.3214.0 Safari/537.36",
        "Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36",
        "Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/55.0.2883.87 Safari/537.36",
        "Mozilla/5.0 (Windows; U; Windows NT 5.2) AppleWebKit/525.13 (KHTML, like Gecko) Chrome/0.2.149.27 Safari/525.13",
        "Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10_6_8; en-us) AppleWebKit/534.50 (KHTML, like Gecko) Version/5.1 Safari/534.50",
        "Mozilla/5.0 (Macintosh; U; IntelMac OS X 10_6_8; en-us) AppleWebKit/534.50 (KHTML, like Gecko) Version/5.1Safari/534.50",
        "Mozilla/5.0 (Windows NT 10.0; WOW64; rv:51.0) Gecko/20100101 Firefox/51.0",
        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.1 (KHTML, like Gecko) Chrome/22.0.1207.1 Safari/537.1",
        "Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.1; Trident/5.0",
        "Mozilla/5.0 (Windows; U; Windows NT 6.1; en-us) AppleWebKit/534.50 (KHTML, like Gecko) Version/5.1 Safari/534.50",
        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.6 (KHTML, like Gecko) Chrome/20.0.1092.0 Safari/536.6",
        "Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.6 (KHTML, like Gecko) Chrome/20.0.1090.0 Safari/536.6",
        "Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/537.1 (KHTML, like Gecko) Chrome/19.77.34.5 Safari/537.1",
        "Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10_6_8; en-us) AppleWebKit/534.50 (KHTML, like Gecko) Version/5.1 Safari/534.50",
        "Mozilla/5.0 (Windows NT 6.0) AppleWebKit/536.5 (KHTML, like Gecko) Chrome/19.0.1084.36 Safari/536.5",
        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1063.0 Safari/536.3",
        "Mozilla/5.0 (Windows NT 5.1) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1063.0 Safari/536.3",
        "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1063.0 Safari/536.3",
        "Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1062.0 Safari/536.3",
        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1062.0 Safari/536.3",
        "Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1061.1 Safari/536.3",
        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1061.1 Safari/536.3",
        "Mozilla/5.0 (Windows NT 6.1) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1061.1 Safari/536.3",
        "Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1061.0 Safari/536.3",
        "Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/535.24 (KHTML, like Gecko) Chrome/19.0.1055.1 Safari/535.24"]

    return random.choice(ua_list)


class LianJiaHouse:
    def __init__(self, city, url, page_size, save_file_path):
        """
        初始化
        @param url: 主起始页
        @param page_size: 每一页的出租房屋个数
        """
        # 城市
        self.city = city
        # 主起始页
        self.base_url = url
        # 当前筛选条件下的页面
        self.current_url = url
        # 行政区域
        self.area = []
        # 户型：一室、二室、三室、四室、五室、五室+
        self.rooms_number = ['l1', 'l2', 'l3', 'l4', 'l5', 'l6']
        # 朝向：朝东+朝南+朝西+朝北+南北
        self.orientation = ['f1', 'f2', 'f3', 'f4', 'f5']
        # 起始页码默认为0
        self.start_page = 0
        # 当前条件下的总数据页数
        self.pages = 0
        # 每一页的出租房屋个数，默认page_szie=30
        self.page_size = page_size
        # 最大页数
        self.max_pages = 100
        # 设置最大数据量，测试用
        self.count = 0
        # 本地文件保存地址
        self.save_file_path = save_file_path
        # 所有已经保存的房屋 id，用来验证去重
        self.house_id = self.get_exists_house_id()
        # 保存数据
        self.data_info = []
        # 系统等待时间：最大时间 + 最小时间（单位：秒）
        self.await_max_time = 5
        self.await_min_time = 3
        # 重连次数
        self.retry = 5
        # 设置爬虫头部，建议多设置一些，防止被封
        self.headers = {
            'User-Agent': get_ua(),
        }

    def get_main_page(self):
        """
        进入主起始页
        @return:
        """
        # 获取当前筛选条件下数据总条数
        soup, count_main = self.get_house_count()
        # 如果当前当前筛选条件下的数据个数大于最大可查询个数，则设置第一次查询条件
        if int(count_main) > self.page_size*self.max_pages:
            # 获取当前地市的所有行政区域，当做第一个查询条件
            soup_uls = soup.find('div', attrs={'data-role': 'ershoufang'}).div.find_all('a')
            self.area = self.get_area_list(soup_uls)
            # 遍历行政区域，重新生成筛选条件
            for area in self.area:
                self.get_area_page(area)
        else:
            # 直接获取数据
            self.get_pages(int(count_main), '', '', '')

        # 保存数据到本地
        self.data_to_csv()

    def get_area_page(self, area):
        """
        当前搜索条件：行政区域
        @param area:
        @return:
        """
        # 重新拼接行政区域访问的 url
        self.current_url = self.base_url + area + '/'
        # 获取当前筛选条件下数据总条数
        soup, count_area = self.get_house_count()

        '''如果当前当前筛选条件下的数据个数大于最大可查询个数，则设置第二次查询条件'''
        if int(count_area) > self.page_size * self.max_pages:
            # 遍历居室数量，重新生成筛选条件
            for rooms_number in self.rooms_number:
                self.get_area_and_room_page(area, rooms_number)
        else:
            print('当前筛选条件：{0}， 共 {1} 条数据，正在获取第 {2} 页'.format(area, count_area, self.pages))
            self.get_pages(int(count_area), area, '', '')

    def get_area_and_room_page(self, area, room_number):
        """
        当前搜索条件：行政区域 + 居室数
        @param area: 行政区域
        @param room_number: 居室数
        @return:
        """
        # 重新拼接行政区域 + 居室数访问的 url
        self.current_url = self.base_url + area + '/' + room_number + '/'
        # 获取当前筛选条件下数据总条数
        soup, count_area_rental = self.get_house_count()

        '''如果当前当前筛选条件下的数据个数大于最大可查询个数，则设置第三次查询条件'''
        if int(count_area_rental) > self.page_size * self.max_pages:
            # 遍历朝向，重新生成筛选条件
            for orientation in self.orientation:
                self.get_area_and_room_and_orientation_page(area, room_number, orientation)
        else:
            print('当前搜索条件：{0} {1}， 共 {2} 条数据，正在获取第 {3} 页'.format(
                area, room_number, count_area_rental, self.pages))
            self.get_pages(int(count_area_rental), area, room_number, '')

    def get_area_and_room_and_orientation_page(self, area, room_number, orientation):
        """
        当前搜索条件：行政区域 + 居室数
        @param area: 行政区域
        @param room_number: 居室数
        @param orientation: 朝向
        @return:
        """
        # 重新拼接行政区域 + 居室 + 朝向 访问的 url
        self.current_url = self.base_url + area + '/' + orientation + room_number + '/'
        # 获取当前筛选条件下数据总条数
        soup, count_area_room_orientation = self.get_house_count()

        '''如果当前当前筛选条件下的数据个数大于最大可查询个数，则设置第三次查询条件'''
        if int(count_area_room_orientation) > self.page_size * self.max_pages:
            print('==================无法获取所有数据，当前筛选条件数据个数超过总数，将爬取前100页数据')
            print('当前搜索条件：{0} {1} {2}， 共 {3} 条数据，正在获取第 {4} 页'.format(
                area, room_number, orientation, count_area_room_orientation, self.pages))
            self.get_pages(int(self.page_size * self.max_pages), area, room_number, orientation)

        else:
            print('当前搜索条件：{0} {1} {2}， 共 {3} 条数据，正在获取第 {4} 页'.format(
                area, room_number, orientation, count_area_room_orientation, self.pages))
            self.get_pages(int(count_area_room_orientation), area, room_number, orientation)

    def get_pages(self, count_number, area, rental_method, room_number):
        """
        根据查询到的页面总数据，确定分页
        @param count_number: 总数据量
        @param area: 区域
        @param rental_method: 出租方式
        @param room_number:居室数
        @return:
        """
        # 确定页数
        self.pages = int(count_number/self.page_size) \
            if (count_number%self.page_size) == 0 else int(count_number/self.page_size)+1

        '''遍历每一页'''
        for page_index in range(1, self.pages+1):
            self.current_url = self.base_url + area + '/' + 'pg' + str(page_index) + rental_method + room_number + '/'
            # 解析当前页的房屋信息，获取到每一个房屋的详细链接
            self.get_per_house()
            page_index += 1
            # 休眠 2 秒
            time.sleep(2)

    def get_per_house(self):
        """
        解析每一页中的每一个房屋的详细链接
        @return:
        """
        # 爬取当前页码的数据
        response = requests.get(url=self.current_url, headers=self.headers, timeout=10)
        soup = BeautifulSoup(response.text, 'html.parser')
        print(self.current_url)
        # ul 目录前面的同一级目录是 div，通过此方式进行定位，可避免最后一页的 ul 出现变动的问题
        soup_ul_list = soup.find('div', class_='bigImgList', attrs={'log-mod': 'list'}).next_sibling
        # soup_ul_list = soup.find('ul', class_='sellListContent', attrs={'log-mod': 'list'})
        # 遍历获取每一个 li 的房屋详情链接和房屋地址
        for soup_li in soup_ul_list.find_all("li"):
            # 定位并获取每一个房屋的详情链接
            detail_href = soup_li.a.get('href')
            # 获取详细链接的编号作为房屋唯一id
            house_id = detail_href.split('/')[-1].replace('.html', '')
            # 如果当前房屋信息已经爬取过
            if self.check_exist(house_id):
                print('房屋id：{0} 已经保存，不再重复爬取！'.format(house_id))
            else:
                # 解析当前房屋的详细数据
                self.get_house_content(detail_href, house_id)

        return ""

    def get_house_content(self, href, house_id):
        """
        获取房屋详细信息页面的内容
        @param href: 详细页面链接
        @param house_id: 上个页面传递的房租id
        @return:
        """
        # 生成一个有序字典，保存房屋结果
        house_info = OrderedDict()
        for i in range(0, self.retry):
            try:
                # 随机休眠3-8 秒
                time.sleep(random.randint(self.await_min_time, self.await_max_time))
                '''爬取页面，获得详细数据'''
                response = requests.get(url=href, headers=self.headers, timeout=10)
                soup = BeautifulSoup(response.text, 'html.parser')
                """解析数据"""
                # 标题数据
                soup_aroundInfo = soup.find('div', class_='aroundInfo')
                house_info['house_address'] = soup_aroundInfo.find('div', class_='communityName').a.text
                print(self.current_url, house_id, house_info['house_address'])

                soup_area = soup_aroundInfo.find('div', class_='areaName').find('span', class_='info')
                house_info['house_region'] = soup_area.find_all('a')[0].text
                house_info['house_area'] = soup_area.find_all('a')[1].text
                house_info['house_id'] = house_id
                # 价格数据
                soup_priceBox = soup.find('div', class_='priceBox')
                if soup_priceBox != None:
                    soup_price = soup_priceBox.find_all("p")
                    house_info['total_price'] = soup_price[0].span.get_text()
                    house_info['unit_price'] = soup_price[1].span.get_text()
                else:
                    house_info['total_price'] = soup.find('span', class_='total').get_text()
                    house_info['unit_price'] = soup.find('span', class_='unitPriceValue').get_text()
                # 基本信息
                soup_base_info = soup.find('div', class_='base').find('div', class_='content').ul.find_all("li")
                house_info['house_layout'] = soup_base_info[0].get_text()
                house_info['house_floor'] = soup_base_info[1].get_text()
                house_info['house_rental_area'] = soup_base_info[2].get_text()
                # 区分别墅的基本信息
                if len(soup_base_info) > 10:
                    house_info['house_structure'] = soup_base_info[3].get_text()
                    house_info['house_inner_area'] = soup_base_info[4].get_text()
                    house_info['house_building_type'] = soup_base_info[5].get_text()
                    house_info['house_orientation'] = soup_base_info[6].get_text()
                    house_info['house_building_structure'] = soup_base_info[7].get_text()
                    house_info['house_decoration'] = soup_base_info[8].get_text()
                    house_info['house_elevator_sytle'] = soup_base_info[9].get_text()
                    house_info['house_elevator'] = soup_base_info[10].get_text()
                else:
                    house_info['house_inner_area'] = soup_base_info[3].get_text()
                    house_info['house_orientation'] = soup_base_info[4].get_text()
                    house_info['house_building_structure'] = soup_base_info[5].get_text()
                    house_info['house_decoration'] = soup_base_info[6].get_text()
                    house_info['house_building_type'] = soup_base_info[7].get_text()
                    house_info['house_structure'] = ""
                    house_info['house_elevator_sytle'] = ""
                    house_info['house_elevator'] = ""

                # 交易属性
                soup_transaction_info = soup.find('div', class_='transaction').find('div', class_='content').ul.find_all("li")
                house_info['house_listing_time'] = soup_transaction_info[0].find_all('span')[1].text
                house_info['house_transaction_type'] = soup_transaction_info[1].find_all('span')[1].text
                house_info['house_last_time'] = soup_transaction_info[2].find_all('span')[1].text
                house_info['house_useage'] = soup_transaction_info[3].find_all('span')[1].text
                house_info['house_years'] = soup_transaction_info[4].find_all('span')[1].text
                house_info['house_property'] = soup_transaction_info[5].find_all('span')[1].text
                house_info['house_mortgage_info'] = soup_transaction_info[6].find_all('span')[1]['title']
                house_info['house_book'] = soup_transaction_info[7].find_all('span')[1].text
                if len(soup_transaction_info) > 8:
                    house_info['house_fx_id'] = soup_transaction_info[8].find_all('span')[1].text
                else:
                    house_info['house_fx_id'] = ''

                '''解析经纬度数据'''
                location_str = response.text[re.search(r"resblockPosition:", response.text).span()[0]:
                                             re.search(r"cityId:", response.text).span()[0]]
                location_arr = location_str.split("'")[1].split(",")
                house_info['house_longitude'] = location_arr[0]
                house_info['house_latitude'] = location_arr[1]
                house_info['city'] = self.city

                # 保存当前信息
                self.data_info.append(house_info)
                self.count += 1

                '''超过10条数据，保存到本地'''
                if len(self.data_info) >= 10:
                    self.data_to_csv()
                # 处理无异常在，跳出循环，否则，进行重试
                break
            except Exception as e:
                print(e)
                print('爬取数据异常，重新尝试爬取数据。爬取地址：{0}'.format(href))

    def check_exist(self, house_id):
        """
        检查当前要获取的房屋数据是否已经存在
        @param house_id:
        @return:
        """
        # 通过检查当前数据中 房屋id 是否存在
        if house_id in self.house_id:
            return True
        else:
            self.house_id.append(house_id)
            return False

    def get_exists_house_id(self):
        """
        通过已经爬取到的房屋信息，并获取房屋id
        @return:
        """
        if os.path.exists(self.save_file_path):
            df_data = pd.read_csv(self.save_file_path, encoding='utf-8', )
            df_data['house_id'] = df_data['house_id'].astype(str)
            return df_data['house_id'].to_list()
        else:
            return []

    def data_to_csv(self):
        """
        保存/追加数据到本地
        @return:
        """
        # 获取数据并保存成 DataFrame
        df_data = pd.DataFrame(self.data_info)

        if os.path.exists(self.save_file_path) and os.path.getsize(self.save_file_path):
            # 追加写入文件
            df_data.to_csv(self.save_file_path, mode='a', encoding='utf-8', header=False, index=False)
        else:
            # 写入文件，带表头
            df_data.to_csv(self.save_file_path, mode='a', encoding='utf-8', index=False)

        print("save success!")
        # 清空当前 数据集
        self.data_info = []

    def get_house_count(self):
        """
        获取当前筛选条件下的房屋数据个数
        @param text:
        @return:
        """
        # 爬取区域起始页面的数据
        response = requests.get(url=self.current_url, headers=self.headers)
        # 通过 BeautifulSoup 进行页面解析
        soup = BeautifulSoup(response.text, 'html.parser')
        # 获取数据总条数
        count = soup.find('h2', class_='total fl').find('span').string.lstrip()

        return soup, count

    def get_area_list(self, soup_uls):
        """
        获取地市的所有行政区域信息，并保存
        @param soup_uls:
        @return:
        """
        area_list = []
        for soup_ul in soup_uls:
            # 获取 ul 中的 a 标签的 href 信息中的区域属性
            href = soup_ul.get('href')
            # 跳过第一条数据
            if href.endswith('/ershoufang/'):
                continue
            else:
                # 获取区域数据，保存到列表中
                area_list.append(href.replace('/ershoufang/', '').replace('/', ''))

        return area_list


if __name__ == '__main__':
    city_number = 'jn'
    city_name = '济南'
    url = 'https://{0}.lianjia.com/ershoufang/'.format(city_number)
    page_size = 30
    save_file_path = r'二手房数据-sz.csv'
    lianjia_house = LianJiaHouse(city_name, url, page_size, save_file_path)
    lianjia_house.get_main_page()
# Out:
# 当前搜索条件：lixia l1， 共 1766  条数据，正在获取第 0 页
# https://jn.lianjia.com/ershoufang/lixia/pg1l1/
# 房屋id：103116716224 已经保存，不再重复爬取！
# 房屋id：103117843780 已经保存，不再重复爬取！
# 房屋id：103117115650 已经保存，不再重复爬取！
# 房屋id：103117742802 已经保存，不再重复爬取！
# 房屋id：103116878065 已经保存，不再重复爬取！
# 房屋id：103116541142 已经保存，不再重复爬取！
# 房屋id：103117336515 已经保存，不再重复爬取！
# 房屋id：103117423903 已经保存，不再重复爬取！
# 房屋id：103116852286 已经保存，不再重复爬取！
# 房屋id：103113947440 已经保存，不再重复爬取！
# 房屋id：103116878666 已经保存，不再重复爬取！
# 房屋id：103115093996 已经保存，不再重复爬取！
# 房屋id：103115873550 已经保存，不再重复爬取！
# 房屋id：103117527408 已经保存，不再重复爬取！
# 房屋id：103108030493 已经保存，不再重复爬取！
# 房屋id：103117876110 已经保存，不再重复爬取！
# 房屋id：103117827107 已经保存，不再重复爬取！
# 房屋id：103117817631 已经保存，不再重复爬取！
# 房屋id：103102007040 已经保存，不再重复爬取！
# 房屋id：103115051422 已经保存，不再重复爬取！
# 房屋id：103117579704 已经保存，不再重复爬取！
# 房屋id：103117541686 已经保存，不再重复爬取！
# 房屋id：103117569436 已经保存，不再重复爬取！
# 房屋id：103117592616 已经保存，不再重复爬取！
# 房屋id：103117808735 已经保存，不再重复爬取！
# 房屋id：103116745915 已经保存，不再重复爬取！
# 房屋id：103117906498 已经保存，不再重复爬取！
# 房屋id：103107746405 已经保存，不再重复爬取！
# 房屋id：103110834404 已经保存，不再重复爬取！
# 房屋id：103114964744 已经保存，不再重复爬取！
# https://jn.lianjia.com/ershoufang/lixia/pg2l1/
# 房屋id：103107221490 已经保存，不再重复爬取！
# 房屋id：103114621550 已经保存，不再重复爬取！
# 房屋id：103116755082 已经保存，不再重复爬取！
# 房屋id：103115378019 已经保存，不再重复爬取！
# 房屋id：103117668437 已经保存，不再重复爬取！
# 房屋id：103117650265 已经保存，不再重复爬取！
# 房屋id：103117523268 已经保存，不再重复爬取！
# 房屋id：103117630653 已经保存，不再重复爬取！
# 房屋id：103117725082 已经保存，不再重复爬取！
# 房屋id：103117906701 已经保存，不再重复爬取！
# 房屋id：103117885237 已经保存，不再重复爬取！
# 房屋id：103102421997 已经保存，不再重复爬取！
# 房屋id：103117404225 已经保存，不再重复爬取！
# 房屋id：103117613179 已经保存，不再重复爬取！
# 房屋id：103117587229 已经保存，不再重复爬取！
# 房屋id：103117623325 已经保存，不再重复爬取！
# 房屋id：103117666488 已经保存，不再重复爬取！
# 房屋id：103117504763 已经保存，不再重复爬取！
# 房屋id：103117583439 已经保存，不再重复爬取！
# 房屋id：103105540662 已经保存，不再重复爬取！
# 房屋id：103117821103 已经保存，不再重复爬取！
# 房屋id：103117699064 已经保存，不再重复爬取！
# 房屋id：103116400356 已经保存，不再重复爬取！
# 房屋id：103113923068 已经保存，不再重复爬取！
# 房屋id：103113341409 已经保存，不再重复爬取！
# 房屋id：103113719147 已经保存，不再重复爬取！
# 房屋id：103115536193 已经保存，不再重复爬取！
# 房屋id：103106407142 已经保存，不再重复爬取！
# 房屋id：103115017048 已经保存，不再重复爬取！
# 房屋id：103117286961 已经保存，不再重复爬取！
# https://jn.lianjia.com/ershoufang/lixia/pg3l1/
# 房屋id：103117884604 已经保存，不再重复爬取！
# 房屋id：103117937128 已经保存，不再重复爬取！
# 房屋id：103113020447 已经保存，不再重复爬取！
# 房屋id：103117949036 已经保存，不再重复爬取！
# 房屋id：103115866370 已经保存，不再重复爬取！
# 房屋id：103108211788 已经保存，不再重复爬取！
# 房屋id：103117520875 已经保存，不再重复爬取！
# 房屋id：103117148789 已经保存，不再重复爬取！
# 房屋id：103102283508 已经保存，不再重复爬取！
# 房屋id：103113097303 已经保存，不再重复爬取！
# 房屋id：103109760263 已经保存，不再重复爬取！
# 房屋id：103109873511 已经保存，不再重复爬取！
# 房屋id：103116752505 已经保存，不再重复爬取！
# 房屋id：103115580493 已经保存，不再重复爬取！
# 房屋id：103115246646 已经保存，不再重复爬取！
# 房屋id：103117051162 已经保存，不再重复爬取！
# 房屋id：103114997411 已经保存，不再重复爬取！
# 房屋id：103110070702 已经保存，不再重复爬取！
# 房屋id：103115878949 已经保存，不再重复爬取！
# 房屋id：103114398218 已经保存，不再重复爬取！
# 房屋id：103114120991 已经保存，不再重复爬取！
# 房屋id：103113365430 已经保存，不再重复爬取！
# 房屋id：103115527574 已经保存，不再重复爬取！
# 房屋id：103116306958 已经保存，不再重复爬取！
# 房屋id：103106161969 已经保存，不再重复爬取！
# 房屋id：103112687068 已经保存，不再重复爬取！
# 房屋id：103114977660 已经保存，不再重复爬取！
# 房屋id：103116352719 已经保存，不再重复爬取！
# 房屋id：103114237577 已经保存，不再重复爬取！
# 房屋id：103111930338 已经保存，不再重复爬取！
# https://jn.lianjia.com/ershoufang/lixia/pg4l1/
# 房屋id：103117483133 已经保存，不再重复爬取！
# 房屋id：103113440053 已经保存，不再重复爬取！
# 房屋id：103109264465 已经保存，不再重复爬取！
# 房屋id：103116943725 已经保存，不再重复爬取！
# 房屋id：103113438393 已经保存，不再重复爬取！
# 房屋id：103115677098 已经保存，不再重复爬取！
# 房屋id：103107721361 已经保存，不再重复爬取！
# 房屋id：103114952709 已经保存，不再重复爬取！
# 房屋id：103116543381 已经保存，不再重复爬取！
# 房屋id：103116351241 已经保存，不再重复爬取！
# 房屋id：103113842251 已经保存，不再重复爬取！
# 房屋id：103117818301 已经保存，不再重复爬取！
# 房屋id：103117901968 已经保存，不再重复爬取！
# 房屋id：103117959926 已经保存，不再重复爬取！
# 房屋id：103109207318 已经保存，不再重复爬取！
# 房屋id：103115327258 已经保存，不再重复爬取！
# 房屋id：103102570624 已经保存，不再重复爬取！
# 房屋id：103116910903 已经保存，不再重复爬取！
# 房屋id：103116419335 已经保存，不再重复爬取！
# 房屋id：103113566366 已经保存，不再重复爬取！
# 房屋id：103113667725 已经保存，不再重复爬取！
# 房屋id：103110180053 已经保存，不再重复爬取！
# 房屋id：103111093669 已经保存，不再重复爬取！
# 房屋id：103116785728 已经保存，不再重复爬取！
# 房屋id：103103852099 已经保存，不再重复爬取！
# 房屋id：103103954046 已经保存，不再重复爬取！
# 房屋id：103112843124 已经保存，不再重复爬取！
# 房屋id：103114666320 已经保存，不再重复爬取！
# 房屋id：103117211496 已经保存，不再重复爬取！
# 房屋id：103108179443 已经保存，不再重复爬取！
# https://jn.lianjia.com/ershoufang/lixia/pg5l1/
# 房屋id：103117067120 已经保存，不再重复爬取！
# 房屋id：103116817156 已经保存，不再重复爬取！
# 房屋id：103106280836 已经保存，不再重复爬取！
# 房屋id：103114645488 已经保存，不再重复爬取！
# 房屋id：103114029401 已经保存，不再重复爬取！
# 房屋id：103116271767 已经保存，不再重复爬取！
# 房屋id：103115593586 已经保存，不再重复爬取！
# 房屋id：103105426559 已经保存，不再重复爬取！
# 房屋id：103110755986 已经保存，不再重复爬取！
# 房屋id：103116433533 已经保存，不再重复爬取！
# 房屋id：103106807890 已经保存，不再重复爬取！
# 房屋id：103108476163 已经保存，不再重复爬取！
# 房屋id：103104525650 已经保存，不再重复爬取！
# 房屋id：103106417116 已经保存，不再重复爬取！
# 房屋id：103116096680 已经保存，不再重复爬取！
# 房屋id：103108090726 已经保存，不再重复爬取！
# 房屋id：103116118225 已经保存，不再重复爬取！
# 房屋id：103116024574 已经保存，不再重复爬取！
# 房屋id：103115300043 已经保存，不再重复爬取！
# 房屋id：103110015529 已经保存，不再重复爬取！
# 房屋id：103116799075 已经保存，不再重复爬取！
# 房屋id：103115841980 已经保存，不再重复爬取！
# 房屋id：103106630296 已经保存，不再重复爬取！
# 房屋id：103112807789 已经保存，不再重复爬取！
# 房屋id：103111535773 已经保存，不再重复爬取！
# 房屋id：103113492666 已经保存，不再重复爬取！
# 房屋id：103103699368 已经保存，不再重复爬取！
# 房屋id：103117620662 已经保存，不再重复爬取！
# 房屋id：103117579452 已经保存，不再重复爬取！
# 房屋id：103117654157 已经保存，不再重复爬取！
# https://jn.lianjia.com/ershoufang/lixia/pg6l1/
# 房屋id：103117531332 已经保存，不再重复爬取！
# 房屋id：103117555633 已经保存，不再重复爬取！
# 房屋id：103117513194 已经保存，不再重复爬取！
# 房屋id：103117660891 已经保存，不再重复爬取！
# 房屋id：103117710758 已经保存，不再重复爬取！
# 房屋id：103117620031 已经保存，不再重复爬取！
# 房屋id：103102275996 已经保存，不再重复爬取！
# 房屋id：103102224051 已经保存，不再重复爬取！
# 房屋id：103117582003 已经保存，不再重复爬取！
# 房屋id：103103552335 已经保存，不再重复爬取！
# 房屋id：103116402648 已经保存，不再重复爬取！
# 房屋id：103110860729 已经保存，不再重复爬取！
# 房屋id：103113778848 已经保存，不再重复爬取！
# 房屋id：103109768411 已经保存，不再重复爬取！
# 房屋id：103112226676 已经保存，不再重复爬取！
# 房屋id：103117774675 已经保存，不再重复爬取！
# 房屋id：103116940147 已经保存，不再重复爬取！
# 房屋id：103114313250 已经保存，不再重复爬取！
# 房屋id：103115494897 已经保存，不再重复爬取！
# 房屋id：103117760421 已经保存，不再重复爬取！
# 房屋id：103114279842 已经保存，不再重复爬取！
# 房屋id：103115472570 已经保存，不再重复爬取！
# 房屋id：103116912244 已经保存，不再重复爬取！
# 房屋id：103117022601 已经保存，不再重复爬取！
# 房屋id：103116103574 已经保存，不再重复爬取！
# 房屋id：103114717377 已经保存，不再重复爬取！
# 房屋id：103114055339 已经保存，不再重复爬取！
# 房屋id：103114990057 已经保存，不再重复爬取！
# 房屋id：103117771959 已经保存，不再重复爬取！
# 房屋id：103115145332 已经保存，不再重复爬取！
# https://jn.lianjia.com/ershoufang/lixia/pg7l1/
# 房屋id：103116925317 已经保存，不再重复爬取！
# 房屋id：103115145332 已经保存，不再重复爬取！
# 房屋id：103116845604 已经保存，不再重复爬取！
# 房屋id：103114206912 已经保存，不再重复爬取！
# 房屋id：103114835075 已经保存，不再重复爬取！
# 房屋id：103117474022 已经保存，不再重复爬取！
# 房屋id：103116015695 已经保存，不再重复爬取！
# 房屋id：103117570241 已经保存，不再重复爬取！
# 房屋id：103105040348 已经保存，不再重复爬取！
# 房屋id：103104728007 已经保存，不再重复爬取！
# 房屋id：103104282899 已经保存，不再重复爬取！
# 房屋id：103106935143 已经保存，不再重复爬取！
# 房屋id：103112290481 已经保存，不再重复爬取！
# 房屋id：103113569548 已经保存，不再重复爬取！
# 房屋id：103111577850 已经保存，不再重复爬取！
# 房屋id：103114766817 已经保存，不再重复爬取！
# 房屋id：103110412865 已经保存，不再重复爬取！
# 房屋id：103105709602 已经保存，不再重复爬取！
# 房屋id：103114485624 已经保存，不再重复爬取！
# 房屋id：103116553099 已经保存，不再重复爬取！
# 房屋id：103113014955 已经保存，不再重复爬取！
# 房屋id：103117908877 已经保存，不再重复爬取！
# 房屋id：103115353141 已经保存，不再重复爬取！
# 房屋id：103107917818 已经保存，不再重复爬取！
# 房屋id：103103652688 已经保存，不再重复爬取！
# 房屋id：103116704754 已经保存，不再重复爬取！
# 房屋id：103105020981 已经保存，不再重复爬取！
# 房屋id：103116068590 已经保存，不再重复爬取！
# 房屋id：103115196429 已经保存，不再重复爬取！
# 房屋id：103115120288 已经保存，不再重复爬取！
# https://jn.lianjia.com/ershoufang/lixia/pg8l1/
# 房屋id：103112788764 已经保存，不再重复爬取！
# 房屋id：103116898305 已经保存，不再重复爬取！
# 房屋id：103111013535 已经保存，不再重复爬取！
# 房屋id：103107721187 已经保存，不再重复爬取！
# 房屋id：103114976405 已经保存，不再重复爬取！
# 房屋id：103115572150 已经保存，不再重复爬取！
# 房屋id：103117015543 已经保存，不再重复爬取！
# 房屋id：103115882977 已经保存，不再重复爬取！
# 房屋id：103109826391 已经保存，不再重复爬取！
# 房屋id：103115231386 已经保存，不再重复爬取！
# 房屋id：103108199413 已经保存，不再重复爬取！
# 房屋id：103117905480 已经保存，不再重复爬取！
# 房屋id：103110189237 已经保存，不再重复爬取！
# 房屋id：103116744479 已经保存，不再重复爬取！
# 房屋id：103117355285 已经保存，不再重复爬取！
# 房屋id：103115968903 已经保存，不再重复爬取！
# 房屋id：103111328343 已经保存，不再重复爬取！
# 房屋id：103117046466 已经保存，不再重复爬取！
# 房屋id：103113071539 已经保存，不再重复爬取！
# 房屋id：103117898640 已经保存，不再重复爬取！
# 房屋id：103117954916 已经保存，不再重复爬取！
# 房屋id：103103894888 已经保存，不再重复爬取！
# 房屋id：103113316831 已经保存，不再重复爬取！
# 房屋id：103108869987 已经保存，不再重复爬取！
# 房屋id：103117303790 已经保存，不再重复爬取！
# 房屋id：103117432941 已经保存，不再重复爬取！
# 房屋id：103117957826 已经保存，不再重复爬取！
# 房屋id：103115817157 已经保存，不再重复爬取！
# 房屋id：103116447122 已经保存，不再重复爬取！
# 房屋id：103115564455 已经保存，不再重复爬取！
# https://jn.lianjia.com/ershoufang/lixia/pg9l1/
# 房屋id：103114844510 已经保存，不再重复爬取！
# 房屋id：103113849286 已经保存，不再重复爬取！
# 房屋id：103112752413 已经保存，不再重复爬取！
# 房屋id：103117918220 已经保存，不再重复爬取！
# 房屋id：103107757845 已经保存，不再重复爬取！
# 房屋id：103117953524 已经保存，不再重复爬取！
# 房屋id：103117753487 已经保存，不再重复爬取！
# 房屋id：103117766217 已经保存，不再重复爬取！
# 房屋id：103113892506 已经保存，不再重复爬取！
# 房屋id：103113892713 已经保存，不再重复爬取！
# 房屋id：103112412536 已经保存，不再重复爬取！
# 房屋id：103115363332 已经保存，不再重复爬取！
# 房屋id：103115993006 已经保存，不再重复爬取！
# 房屋id：103112668526 已经保存，不再重复爬取！
# 房屋id：103112037588 已经保存，不再重复爬取！
# 房屋id：103111961613 已经保存，不再重复爬取！
# 房屋id：103108061603 已经保存，不再重复爬取！
# 房屋id：103110133587 已经保存，不再重复爬取！
# 房屋id：103114307292 已经保存，不再重复爬取！
# 房屋id：103113549766 已经保存，不再重复爬取！
# 房屋id：103105686668 已经保存，不再重复爬取！
# 房屋id：103115327373 已经保存，不再重复爬取！
# 房屋id：103115500849 已经保存，不再重复爬取！
# 房屋id：103115088047 已经保存，不再重复爬取！
# 房屋id：103108671452 已经保存，不再重复爬取！
# 房屋id：103116573268 已经保存，不再重复爬取！
# 房屋id：103110368065 已经保存，不再重复爬取！
# 房屋id：103109850043 已经保存，不再重复爬取！
# 房屋id：103115926851 已经保存，不再重复爬取！
# 房屋id：103113667795 已经保存，不再重复爬取！
# https://jn.lianjia.com/ershoufang/lixia/pg10l1/
# 房屋id：103115855774 已经保存，不再重复爬取！
# 房屋id：103108481879 已经保存，不再重复爬取！
# 房屋id：103115753900 已经保存，不再重复爬取！
# 房屋id：103113850391 已经保存，不再重复爬取！
# 房屋id：103110346699 已经保存，不再重复爬取！
# 房屋id：103107970251 已经保存，不再重复爬取！
# 房屋id：103114763296 已经保存，不再重复爬取！
# 房屋id：103112892054 已经保存，不再重复爬取！
# 房屋id：103113549910 已经保存，不再重复爬取！
# 房屋id：103113913428 已经保存，不再重复爬取！
# 房屋id：103106662437 已经保存，不再重复爬取！
# 房屋id：103113260490 已经保存，不再重复爬取！
# 房屋id：103107505256 已经保存，不再重复爬取！
# 房屋id：103110455715 已经保存，不再重复爬取！
# 房屋id：103108821373 已经保存，不再重复爬取！
# 房屋id：103110711418 已经保存，不再重复爬取！
# 房屋id：103105313100 已经保存，不再重复爬取！
# 房屋id：103116021686 已经保存，不再重复爬取！
# 房屋id：103109018284 已经保存，不再重复爬取！
# 房屋id：103109606305 已经保存，不再重复爬取！
# 房屋id：103111134394 已经保存，不再重复爬取！
# 房屋id：103115855799 已经保存，不再重复爬取！
# 房屋id：103112962562 已经保存，不再重复爬取！
# 房屋id：103108967788 已经保存，不再重复爬取！
# 房屋id：103117115088 已经保存，不再重复爬取！
# 房屋id：103113780173 已经保存，不再重复爬取！
# 房屋id：103108238961 已经保存，不再重复爬取！
# 房屋id：103115327303 已经保存，不再重复爬取！
# 房屋id：103113436967 已经保存，不再重复爬取！
# 房屋id：103110095498 已经保存，不再重复爬取！
# https://jn.lianjia.com/ershoufang/lixia/pg11l1/
# 房屋id：103114761058 已经保存，不再重复爬取！
# 房屋id：103117424010 已经保存，不再重复爬取！
# 房屋id：103115327303 已经保存，不再重复爬取！
# 房屋id：103115818436 已经保存，不再重复爬取！
# 房屋id：103107595668 已经保存，不再重复爬取！
# 房屋id：103116961632 已经保存，不再重复爬取！
# 房屋id：103108967788 已经保存，不再重复爬取！
# 房屋id：103112962562 已经保存，不再重复爬取！
# 房屋id：103112072809 已经保存，不再重复爬取！
# 房屋id：103116289102 已经保存，不再重复爬取！
# 房屋id：103111604632 已经保存，不再重复爬取！
# 房屋id：103108624854 已经保存，不再重复爬取！
# 房屋id：103107555565 已经保存，不再重复爬取！
# 房屋id：103116778054 已经保存，不再重复爬取！
# 房屋id：103111018929 已经保存，不再重复爬取！
# 房屋id：103116820556 已经保存，不再重复爬取！
# 房屋id：103103751002 已经保存，不再重复爬取！
# 房屋id：103115568956 已经保存，不再重复爬取！
# 房屋id：103115968128 已经保存，不再重复爬取！
# 房屋id：103116368581 已经保存，不再重复爬取！
# 房屋id：103116211095 已经保存，不再重复爬取！
# 房屋id：103116064396 已经保存，不再重复爬取！
# 房屋id：103116798802 已经保存，不再重复爬取！
# 房屋id：103116819238 已经保存，不再重复爬取！
# 房屋id：103115190999 已经保存，不再重复爬取！
# 房屋id：103114082884 已经保存，不再重复爬取！
# 房屋id：103111354378 已经保存，不再重复爬取！
# 房屋id：103111967897 已经保存，不再重复爬取！
# 房屋id：103114041135 已经保存，不再重复爬取！
# 房屋id：103107374855 已经保存，不再重复爬取！
# https://jn.lianjia.com/ershoufang/lixia/pg12l1/
# 房屋id：103111237626 已经保存，不再重复爬取！
# 房屋id：103102782362 已经保存，不再重复爬取！
# 房屋id：103105987348 已经保存，不再重复爬取！
# 房屋id：103115306261 已经保存，不再重复爬取！
# 房屋id：103107284102 已经保存，不再重复爬取！
# 房屋id：103113575720 已经保存，不再重复爬取！
# 房屋id：103113391568 已经保存，不再重复爬取！
# 房屋id：103111495965 已经保存，不再重复爬取！
# 房屋id：103112168722 已经保存，不再重复爬取！
# 房屋id：103114334204 已经保存，不再重复爬取！
# 房屋id：103115122039 已经保存，不再重复爬取！
# 房屋id：103107050079 已经保存，不再重复爬取！
# 房屋id：103111860955 已经保存，不再重复爬取！
# 房屋id：103114189804 已经保存，不再重复爬取！
# 房屋id：103108645199 已经保存，不再重复爬取！
# 房屋id：103111305937 已经保存，不再重复爬取！
# 房屋id：103107994489 已经保存，不再重复爬取！
# 房屋id：103106943256 已经保存，不再重复爬取！
# 房屋id：103116479084 已经保存，不再重复爬取！
# 房屋id：103105836376 已经保存，不再重复爬取！
# 房屋id：103109373002 已经保存，不再重复爬取！
# 房屋id：103114448167 已经保存，不再重复爬取！
# 房屋id：103115468965 已经保存，不再重复爬取！
# 房屋id：103110255387 已经保存，不再重复爬取！
# 房屋id：103115101314 已经保存，不再重复爬取！
# 房屋id：103115101261 已经保存，不再重复爬取！
# 房屋id：103110677147 已经保存，不再重复爬取！
# 房屋id：103111581740 已经保存，不再重复爬取！
# 房屋id：103112398207 已经保存，不再重复爬取！
# 房屋id：103115561368 已经保存，不再重复爬取！
# https://jn.lianjia.com/ershoufang/lixia/pg13l1/
# 房屋id：103114581030 已经保存，不再重复爬取！
# 房屋id：103112436388 已经保存，不再重复爬取！
# 房屋id：103110677147 已经保存，不再重复爬取！
# 房屋id：103108501216 已经保存，不再重复爬取！
# 房屋id：103113018170 已经保存，不再重复爬取！
# 房屋id：103116111128 已经保存，不再重复爬取！
# 房屋id：103117139851 已经保存，不再重复爬取！
# 房屋id：103107559827 已经保存，不再重复爬取！
# 房屋id：103114089935 已经保存，不再重复爬取！
# 房屋id：103117358901 已经保存，不再重复爬取！
# 房屋id：103116971404 已经保存，不再重复爬取！
# 房屋id：103102573430 已经保存，不再重复爬取！
# 房屋id：103117374697 已经保存，不再重复爬取！
# 房屋id：103109762485 已经保存，不再重复爬取！
# 房屋id：103114137578 已经保存，不再重复爬取！
# 房屋id：103109186419 已经保存，不再重复爬取！
# 房屋id：103110170089 已经保存，不再重复爬取！
# 房屋id：103116807164 已经保存，不再重复爬取！
# 房屋id：103115051705 已经保存，不再重复爬取！
# 房屋id：103116894204 已经保存，不再重复爬取！
# 房屋id：103116628390 已经保存，不再重复爬取！
# 房屋id：103111588644 已经保存，不再重复爬取！
# 房屋id：103105180569 已经保存，不再重复爬取！
# 房屋id：103114979625 已经保存，不再重复爬取！
# 房屋id：103117571415 已经保存，不再重复爬取！
# 房屋id：103117654185 已经保存，不再重复爬取！
# 房屋id：103117741188 已经保存，不再重复爬取！
# 房屋id：103117649945 已经保存，不再重复爬取！
# 房屋id：103116491431 已经保存，不再重复爬取！
# 房屋id：103113928194 已经保存，不再重复爬取！
# https://jn.lianjia.com/ershoufang/lixia/pg14l1/
# 房屋id：103117601703 已经保存，不再重复爬取！
# 房屋id：103117602460 已经保存，不再重复爬取！
# 房屋id：103117601515 已经保存，不再重复爬取！
# 房屋id：103117602272 已经保存，不再重复爬取！
# 房屋id：103117530274 已经保存，不再重复爬取！
# 房屋id：103117694514 已经保存，不再重复爬取！
# 房屋id：103117687737 已经保存，不再重复爬取！
# 房屋id：103117549197 已经保存，不再重复爬取！
# 房屋id：103117657607 已经保存，不再重复爬取！
# 房屋id：103117611669 已经保存，不再重复爬取！
# 房屋id：103117596697 已经保存，不再重复爬取！
# 房屋id：103102354309 已经保存，不再重复爬取！
# 房屋id：103117616362 已经保存，不再重复爬取！
# 房屋id：103117551530 已经保存，不再重复爬取！
# 房屋id：103117649786 已经保存，不再重复爬取！
# 房屋id：103117546054 已经保存，不再重复爬取！
# 房屋id：103117562406 已经保存，不再重复爬取！
# 房屋id：103117610110 已经保存，不再重复爬取！
# 房屋id：103117584048 已经保存，不再重复爬取！
# 房屋id：103117736016 已经保存，不再重复爬取！
# 房屋id：103117618653 已经保存，不再重复爬取！
# 房屋id：103111753262 已经保存，不再重复爬取！
# 房屋id：103112372621 已经保存，不再重复爬取！
# 房屋id：103113910570 已经保存，不再重复爬取！
# 房屋id：103111082107 已经保存，不再重复爬取！
# 房屋id：103115929664 已经保存，不再重复爬取！
# 房屋id：103116828183 已经保存，不再重复爬取！
# 房屋id：103112162345 已经保存，不再重复爬取！
# 房屋id：103113031657 已经保存，不再重复爬取！
# 房屋id：103114986415 已经保存，不再重复爬取！
# https://jn.lianjia.com/ershoufang/lixia/pg15l1/
# 房屋id：103115327307 已经保存，不再重复爬取！
# 房屋id：103115141336 已经保存，不再重复爬取！
# 房屋id：103114302678 已经保存，不再重复爬取！
# 房屋id：103115276627 已经保存，不再重复爬取！
# 房屋id：103110553270 已经保存，不再重复爬取！
# 房屋id：103114064332 已经保存，不再重复爬取！
# 房屋id：103109467934 已经保存，不再重复爬取！
# 房屋id：103111259364 已经保存，不再重复爬取！
# 房屋id：103111936854 已经保存，不再重复爬取！
# 房屋id：103110087266 已经保存，不再重复爬取！
# 房屋id：103113589196 已经保存，不再重复爬取！
# 房屋id：103116988474 已经保存，不再重复爬取！
# 房屋id：103114335673 已经保存，不再重复爬取！
# 房屋id：103117361230 已经保存，不再重复爬取！
# 房屋id：103116685890 已经保存，不再重复爬取！
# 房屋id：103103431614 已经保存，不再重复爬取！
# 房屋id：103113198657 已经保存，不再重复爬取！
# 房屋id：103112125895 已经保存，不再重复爬取！
# 房屋id：103113301655 已经保存，不再重复爬取！
# 房屋id：103113375133 已经保存，不再重复爬取！
# 房屋id：103111594054 已经保存，不再重复爬取！
# 房屋id：103116233188 已经保存，不再重复爬取！
# 房屋id：103115198152 已经保存，不再重复爬取！
# 房屋id：103109732570 已经保存，不再重复爬取！
# 房屋id：103116062602 已经保存，不再重复爬取！
# 房屋id：103116215354 已经保存，不再重复爬取！
# 房屋id：103115215462 已经保存，不再重复爬取！
# 房屋id：103111064592 已经保存，不再重复爬取！
# 房屋id：103110538575 已经保存，不再重复爬取！
# 房屋id：103110843843 已经保存，不再重复爬取！
# https://jn.lianjia.com/ershoufang/lixia/pg16l1/
# 房屋id：103110538575 已经保存，不再重复爬取！
# 房屋id：103111064592 已经保存，不再重复爬取！
# 房屋id：103116062602 已经保存，不再重复爬取！
# 房屋id：103110843843 已经保存，不再重复爬取！
# 房屋id：103117025054 已经保存，不再重复爬取！
# 房屋id：103115215462 已经保存，不再重复爬取！
# 房屋id：103111887318 已经保存，不再重复爬取！
# 房屋id：103117125585 已经保存，不再重复爬取！
# 房屋id：103116286662 已经保存，不再重复爬取！
# 房屋id：103113907269 已经保存，不再重复爬取！
# 房屋id：103115029480 已经保存，不再重复爬取！
# 房屋id：103111737122 已经保存，不再重复爬取！
# 房屋id：103117423223 已经保存，不再重复爬取！
# 房屋id：103104593637 已经保存，不再重复爬取！
# 房屋id：103114638753 已经保存，不再重复爬取！
# 房屋id：103112757621 已经保存，不再重复爬取！
# 房屋id：103117809558 已经保存，不再重复爬取！
# 房屋id：103112721066 已经保存，不再重复爬取！
# 房屋id：103108769687 已经保存，不再重复爬取！
# 房屋id：103112715057 已经保存，不再重复爬取！
# 房屋id：103117819085 已经保存，不再重复爬取！
# 房屋id：103105812348 已经保存，不再重复爬取！
# 房屋id：103110871527 已经保存，不再重复爬取！
# 房屋id：103115179642 已经保存，不再重复爬取！
# 房屋id：103115279121 已经保存，不再重复爬取！
# 房屋id：103117258960 已经保存，不再重复爬取！
# 房屋id：103114256176 已经保存，不再重复爬取！
# 房屋id：103107827012 已经保存，不再重复爬取！
# 房屋id：103117349116 已经保存，不再重复爬取！
# 房屋id：103113139930 已经保存，不再重复爬取！
# https://jn.lianjia.com/ershoufang/lixia/pg17l1/
# 房屋id：103112199847 已经保存，不再重复爬取！
# 房屋id：103117349116 已经保存，不再重复爬取！
# 房屋id：103108698010 已经保存，不再重复爬取！
# 房屋id：103116964584 已经保存，不再重复爬取！
# 房屋id：103115074415 已经保存，不再重复爬取！
# 房屋id：103115939636 已经保存，不再重复爬取！
# 房屋id：103116187827 已经保存，不再重复爬取！
# 房屋id：103117794511 已经保存，不再重复爬取！
# 房屋id：103117341637 已经保存，不再重复爬取！
# 房屋id：103116912259 已经保存，不再重复爬取！
# 房屋id：103112763798 已经保存，不再重复爬取！
# 房屋id：103113787874 已经保存，不再重复爬取！
# 房屋id：103114917762 已经保存，不再重复爬取！
# 房屋id：103117783607 已经保存，不再重复爬取！
# 房屋id：103114947511 已经保存，不再重复爬取！
# 房屋id：103105631163 已经保存，不再重复爬取！
# 房屋id：103117232586 已经保存，不再重复爬取！
# 房屋id：103113439029 已经保存，不再重复爬取！
# 房屋id：103113789328 已经保存，不再重复爬取！
# 房屋id：103116968538 已经保存，不再重复爬取！
# 房屋id：103114630054 已经保存，不再重复爬取！
# 房屋id：103117099251 已经保存，不再重复爬取！
# 房屋id：103115961405 已经保存，不再重复爬取！
# 房屋id：103110667928 已经保存，不再重复爬取！
# 房屋id：103116167399 已经保存，不再重复爬取！
# 房屋id：103116794178 已经保存，不再重复爬取！
# 房屋id：103116275623 已经保存，不再重复爬取！
# 房屋id：103117820075 已经保存，不再重复爬取！
# 房屋id：103117425871 已经保存，不再重复爬取！
# 房屋id：103109679403 已经保存，不再重复爬取！
# https://jn.lianjia.com/ershoufang/lixia/pg18l1/
# 房屋id：103109440331 已经保存，不再重复爬取！
# 房屋id：103114516906 已经保存，不再重复爬取！
# 房屋id：103116837166 已经保存，不再重复爬取！
# 房屋id：103114770701 已经保存，不再重复爬取！
# 房屋id：103115054665 已经保存，不再重复爬取！
# 房屋id：103117767020 已经保存，不再重复爬取！
# 房屋id：103103565222 已经保存，不再重复爬取！
# 房屋id：103113075748 已经保存，不再重复爬取！
# 房屋id：103109200820 已经保存，不再重复爬取！
# 房屋id：103110868705 已经保存，不再重复爬取！
# 房屋id：103112398151 已经保存，不再重复爬取！
# 房屋id：103116255187 已经保存，不再重复爬取！
# 房屋id：103117308486 已经保存，不再重复爬取！
# 房屋id：103117853550 已经保存，不再重复爬取！
# 房屋id：103113984461 已经保存，不再重复爬取！
# 房屋id：103113873476 已经保存，不再重复爬取！
# 房屋id：103117871930 已经保存，不再重复爬取！
# 房屋id：103112040060 已经保存，不再重复爬取！
# 房屋id：103110806396 已经保存，不再重复爬取！
# 房屋id：103114576448 已经保存，不再重复爬取！
# 房屋id：103112919226 已经保存，不再重复爬取！
# 房屋id：103115812381 已经保存，不再重复爬取！
# 房屋id：103116021663 已经保存，不再重复爬取！
# 房屋id：103117404326 已经保存，不再重复爬取！
# 房屋id：103117291617 已经保存，不再重复爬取！
# 房屋id：103116426667 已经保存，不再重复爬取！
# 房屋id：103113984697 已经保存，不再重复爬取！
# https://jn.lianjia.com/ershoufang/lixia/pg18l1/ 103102310967 名士mini公馆
# 房屋id：103109417194 已经保存，不再重复爬取！
# 房屋id：103115641502 已经保存，不再重复爬取！
# https://jn.lianjia.com/ershoufang/lixia/pg19l1/
# 房屋id：103110558037 已经保存，不再重复爬取！
# 房屋id：103110913715 已经保存，不再重复爬取！
# 房屋id：103117163597 已经保存，不再重复爬取！
# 房屋id：103115545808 已经保存，不再重复爬取！
# 房屋id：103117279710 已经保存，不再重复爬取！
# 房屋id：103110680853 已经保存，不再重复爬取！
# 房屋id：103113918207 已经保存，不再重复爬取！
# 房屋id：103113818877 已经保存，不再重复爬取！
# 房屋id：103110403379 已经保存，不再重复爬取！
# 房屋id：103117089973 已经保存，不再重复爬取！
# 房屋id：103111563221 已经保存，不再重复爬取！
# 房屋id：103116093389 已经保存，不再重复爬取！
# 房屋id：103117167787 已经保存，不再重复爬取！
# 房屋id：103115057913 已经保存，不再重复爬取！
# 房屋id：103115502100 已经保存，不再重复爬取！
# 房屋id：103114855953 已经保存，不再重复爬取！
# 房屋id：103103917876 已经保存，不再重复爬取！
# 房屋id：103109147186 已经保存，不再重复爬取！
# 房屋id：103113122954 已经保存，不再重复爬取！
# 房屋id：103116284891 已经保存，不再重复爬取！
# 房屋id：103116949741 已经保存，不再重复爬取！
# 房屋id：103117412987 已经保存，不再重复爬取！
# 房屋id：103106632119 已经保存，不再重复爬取！
# 房屋id：103111292969 已经保存，不再重复爬取！
# 房屋id：103109821798 已经保存，不再重复爬取！
# 房屋id：103111986434 已经保存，不再重复爬取！
# 房屋id：103114426627 已经保存，不再重复爬取！
# 房屋id：103108012035 已经保存，不再重复爬取！
# 房屋id：103114873020 已经保存，不再重复爬取！
# 房屋id：103114041174 已经保存，不再重复爬取！
# https://jn.lianjia.com/ershoufang/lixia/pg20l1/
# 房屋id：103114124877 已经保存，不再重复爬取！
# 房屋id：103116917674 已经保存，不再重复爬取！
# 房屋id：103112515848 已经保存，不再重复爬取！
# 房屋id：103112553770 已经保存，不再重复爬取！
# 房屋id：103113048796 已经保存，不再重复爬取！
# 房屋id：103115898431 已经保存，不再重复爬取！
# 房屋id：103117320557 已经保存，不再重复爬取！
# 房屋id：103112668850 已经保存，不再重复爬取！
# 房屋id：103111488300 已经保存，不再重复爬取！
# 房屋id：103112664851 已经保存，不再重复爬取！
# 房屋id：103116299131 已经保存，不再重复爬取！
# 房屋id：103115615092 已经保存，不再重复爬取！
# 房屋id：103113452765 已经保存，不再重复爬取！
# 房屋id：103116569256 已经保存，不再重复爬取！
# 房屋id：103115729403 已经保存，不再重复爬取！
# 房屋id：103117191456 已经保存，不再重复爬取！
# 房屋id：103116125616 已经保存，不再重复爬取！
# 房屋id：103116125646 已经保存，不再重复爬取！
# 房屋id：103116125879 已经保存，不再重复爬取！
# 房屋id：103116125644 已经保存，不再重复爬取！
# 房屋id：103115958594 已经保存，不再重复爬取！
# 房屋id：103105981594 已经保存，不再重复爬取！
# 房屋id：103114588411 已经保存，不再重复爬取！
# 房屋id：103114245795 已经保存，不再重复爬取！
# 房屋id：103110373517 已经保存，不再重复爬取！
# 房屋id：103116375693 已经保存，不再重复爬取！
# 房屋id：103117469609 已经保存，不再重复爬取！
# 房屋id：103107259251 已经保存，不再重复爬取！
# 房屋id：103112121545 已经保存，不再重复爬取！
# 房屋id：103116055983 已经保存，不再重复爬取！
# https://jn.lianjia.com/ershoufang/lixia/pg21l1/
# 房屋id：103111098924 已经保存，不再重复爬取！
# 房屋id：103112121545 已经保存，不再重复爬取！
# 房屋id：103114872965 已经保存，不再重复爬取！
# 房屋id：103107458758 已经保存，不再重复爬取！
# 房屋id：103116940895 已经保存，不再重复爬取！
# 房屋id：103117297320 已经保存，不再重复爬取！
# 房屋id：103116055983 已经保存，不再重复爬取！
# 房屋id：103104730688 已经保存，不再重复爬取！
# 房屋id：103115428567 已经保存，不再重复爬取！
# 房屋id：103107909129 已经保存，不再重复爬取！
# 房屋id：103115678832 已经保存，不再重复爬取！
# 房屋id：103112491695 已经保存，不再重复爬取！
# 房屋id：103110229089 已经保存，不再重复爬取！
# 房屋id：103117379416 已经保存，不再重复爬取！
# 房屋id：103115327342 已经保存，不再重复爬取！
# 房屋id：103109624373 已经保存，不再重复爬取！
# 房屋id：103117080123 已经保存，不再重复爬取！
# 房屋id：103114205276 已经保存，不再重复爬取！
# 房屋id：103115637491 已经保存，不再重复爬取！
# 房屋id：103117171217 已经保存，不再重复爬取！
# 房屋id：103107536008 已经保存，不再重复爬取！
# 房屋id：103116490347 已经保存，不再重复爬取！
# 房屋id：103115135016 已经保存，不再重复爬取！
# 房屋id：103112922224 已经保存，不再重复爬取！
# 房屋id：103106976852 已经保存，不再重复爬取！
# 房屋id：103115332276 已经保存，不再重复爬取！
# 房屋id：103117523807 已经保存，不再重复爬取！
# 房屋id：103104698769 已经保存，不再重复爬取！
# 房屋id：103116235960 已经保存，不再重复爬取！
# 房屋id：103115292889 已经保存，不再重复爬取！
# https://jn.lianjia.com/ershoufang/lixia/pg22l1/
# 房屋id：103106893823 已经保存，不再重复爬取！
# 房屋id：103116890942 已经保存，不再重复爬取！
# 房屋id：103110325959 已经保存，不再重复爬取！
# 房屋id：103114080607 已经保存，不再重复爬取！
# 房屋id：103116833687 已经保存，不再重复爬取！
# 房屋id：103108686811 已经保存，不再重复爬取！
# 房屋id：103111307566 已经保存，不再重复爬取！
# 房屋id：103114539640 已经保存，不再重复爬取！
# 房屋id：103116937557 已经保存，不再重复爬取！
# 房屋id：103117025713 已经保存，不再重复爬取！
# 房屋id：103114825519 已经保存，不再重复爬取！
# 房屋id：103114376678 已经保存，不再重复爬取！
# 房屋id：103111656079 已经保存，不再重复爬取！
# 房屋id：103104321123 已经保存，不再重复爬取！
# 房屋id：103110589545 已经保存，不再重复爬取！
# 房屋id：103114029065 已经保存，不再重复爬取！
# 房屋id：103114352903 已经保存，不再重复爬取！
# 房屋id：103104805440 已经保存，不再重复爬取！
# 房屋id：103117001954 已经保存，不再重复爬取！
# 房屋id：103110185816 已经保存，不再重复爬取！
# 房屋id：103116346113 已经保存，不再重复爬取！
# 房屋id：103108809442 已经保存，不再重复爬取！
# 房屋id：103112727242 已经保存，不再重复爬取！
# 房屋id：103111415593 已经保存，不再重复爬取！
# 房屋id：103110377024 已经保存，不再重复爬取！
# 房屋id：103105655153 已经保存，不再重复爬取！
# 房屋id：103107249547 已经保存，不再重复爬取！
# 房屋id：103115400147 已经保存，不再重复爬取！
# 房屋id：103115122168 已经保存，不再重复爬取！
# 房屋id：103107946516 已经保存，不再重复爬取！
# https://jn.lianjia.com/ershoufang/lixia/pg23l1/
# 房屋id：103112152805 已经保存，不再重复爬取！
# 房屋id：103106844629 已经保存，不再重复爬取！
# 房屋id：103107307332 已经保存，不再重复爬取！
# 房屋id：103116060129 已经保存，不再重复爬取！
# 房屋id：103115311036 已经保存，不再重复爬取！
# 房屋id：103110150221 已经保存，不再重复爬取！
# 房屋id：103115199144 已经保存，不再重复爬取！
# 房屋id：103116648234 已经保存，不再重复爬取！
# 房屋id：103106580031 已经保存，不再重复爬取！
# 房屋id：103113525316 已经保存，不再重复爬取！
# 房屋id：103111622493 已经保存，不再重复爬取！
# 房屋id：103115549967 已经保存，不再重复爬取！
# 房屋id：103112710703 已经保存，不再重复爬取！
# 房屋id：103110025409 已经保存，不再重复爬取！
# 房屋id：103106674773 已经保存，不再重复爬取！
# 房屋id：103111947507 已经保存，不再重复爬取！
# 房屋id：103115517863 已经保存，不再重复爬取！
# 房屋id：103106292479 已经保存，不再重复爬取！
# 房屋id：103114671179 已经保存，不再重复爬取！
# 房屋id：103106136488 已经保存，不再重复爬取！
# 房屋id：103103458674 已经保存，不再重复爬取！
# 房屋id：103116279233 已经保存，不再重复爬取！
# 房屋id：103102778618 已经保存，不再重复爬取！
# 房屋id：103116957947 已经保存，不再重复爬取！
# 房屋id：103105020319 已经保存，不再重复爬取！
# 房屋id：103102705153 已经保存，不再重复爬取！
# 房屋id：103117602310 已经保存，不再重复爬取！
# 房屋id：103117602429 已经保存，不再重复爬取！
# 房屋id：103117602331 已经保存，不再重复爬取！
# 房屋id：103117601728 已经保存，不再重复爬取！
# https://jn.lianjia.com/ershoufang/lixia/pg24l1/
# 房屋id：103117602429 已经保存，不再重复爬取！
# 房屋id：103117602310 已经保存，不再重复爬取！
# 房屋id：103117540779 已经保存，不再重复爬取！
# 房屋id：103117499531 已经保存，不再重复爬取！
# 房屋id：103117694298 已经保存，不再重复爬取！
# 房屋id：103117512827 已经保存，不再重复爬取！
# 房屋id：103117640771 已经保存，不再重复爬取！
# 房屋id：103117722536 已经保存，不再重复爬取！
# 房屋id：103117594581 已经保存，不再重复爬取！
# 房屋id：103117718069 已经保存，不再重复爬取！
# 房屋id：103117526004 已经保存，不再重复爬取！
# 房屋id：103117717593 已经保存，不再重复爬取！
# 房屋id：103117602044 已经保存，不再重复爬取！
# 房屋id：103117679249 已经保存，不再重复爬取！
# 房屋id：103117614900 已经保存，不再重复爬取！
# 房屋id：103117536041 已经保存，不再重复爬取！
# 房屋id：103117727616 已经保存，不再重复爬取！
# 房屋id：103117533043 已经保存，不再重复爬取！
# 房屋id：103104863074 已经保存，不再重复爬取！
# 房屋id：103109272238 已经保存，不再重复爬取！
# 房屋id：103111098045 已经保存，不再重复爬取！
# 房屋id：103116622143 已经保存，不再重复爬取！
# 房屋id：103117035607 已经保存，不再重复爬取！
# 房屋id：103114793448 已经保存，不再重复爬取！
# 房屋id：103114681305 已经保存，不再重复爬取！
# 房屋id：103112991505 已经保存，不再重复爬取！
# 房屋id：103109844925 已经保存，不再重复爬取！
# 房屋id：103114064987 已经保存，不再重复爬取！
# 房屋id：103114839250 已经保存，不再重复爬取！
# 房屋id：103113953714 已经保存，不再重复爬取！
# https://jn.lianjia.com/ershoufang/lixia/pg25l1/
# 房屋id：103113555287 已经保存，不再重复爬取！
# 房屋id：103117436007 已经保存，不再重复爬取！
# 房屋id：103109385561 已经保存，不再重复爬取！
# 房屋id：103110587142 已经保存，不再重复爬取！
# 房屋id：103117082646 已经保存，不再重复爬取！
# 房屋id：103114681170 已经保存，不再重复爬取！
# 房屋id：103117041522 已经保存，不再重复爬取！
# 房屋id：103111488346 已经保存，不再重复爬取！
# 房屋id：103112570170 已经保存，不再重复爬取！
# 房屋id：103117114986 已经保存，不再重复爬取！
# 房屋id：103110626315 已经保存，不再重复爬取！
# 房屋id：103113195198 已经保存，不再重复爬取！
# 房屋id：103112614508 已经保存，不再重复爬取！
# 房屋id：103110721906 已经保存，不再重复爬取！
# 房屋id：103117041583 已经保存，不再重复爬取！
# 房屋id：103106164566 已经保存，不再重复爬取！
# 房屋id：103116520013 已经保存，不再重复爬取！
# 房屋id：103108999852 已经保存，不再重复爬取！
# 房屋id：103108905467 已经保存，不再重复爬取！
# 房屋id：103114049947 已经保存，不再重复爬取！
# 房屋id：103117281044 已经保存，不再重复爬取！
# 房屋id：103115312135 已经保存，不再重复爬取！
# 房屋id：103112174023 已经保存，不再重复爬取！
# 房屋id：103108697246 已经保存，不再重复爬取！
# 房屋id：103117395555 已经保存，不再重复爬取！
# 房屋id：103116896359 已经保存，不再重复爬取！
# 房屋id：103117457386 已经保存，不再重复爬取！
# 房屋id：103117368150 已经保存，不再重复爬取！
# 房屋id：103106826460 已经保存，不再重复爬取！
# 房屋id：103117276969 已经保存，不再重复爬取！
# https://jn.lianjia.com/ershoufang/lixia/pg26l1/
# 房屋id：103110026992 已经保存，不再重复爬取！
# 房屋id：103117368150 已经保存，不再重复爬取！
# 房屋id：103108697246 已经保存，不再重复爬取！
# 房屋id：103115317391 已经保存，不再重复爬取！
# 房屋id：103109000101 已经保存，不再重复爬取！
# 房屋id：103117457386 已经保存，不再重复爬取！
# 房屋id：103105020468 已经保存，不再重复爬取！
# 房屋id：103110514407 已经保存，不再重复爬取！
# 房屋id：103114751113 已经保存，不再重复爬取！
# 房屋id：103117367044 已经保存，不再重复爬取！
# 房屋id：103112574351 已经保存，不再重复爬取！
# 房屋id：103113970900 已经保存，不再重复爬取！
# 房屋id：103117450004 已经保存，不再重复爬取！
# 房屋id：103115015652 已经保存，不再重复爬取！
# 房屋id：103117517557 已经保存，不再重复爬取！
# 房屋id：103113557203 已经保存，不再重复爬取！
# 房屋id：103104690790 已经保存，不再重复爬取！
# 房屋id：103104216495 已经保存，不再重复爬取！
# 房屋id：103105498807 已经保存，不再重复爬取！
# 房屋id：103113929628 已经保存，不再重复爬取！
# 房屋id：103114570993 已经保存，不再重复爬取！
# 房屋id：103110576949 已经保存，不再重复爬取！
# 房屋id：103113932025 已经保存，不再重复爬取！
# 房屋id：103114388696 已经保存，不再重复爬取！
# 房屋id：103107427121 已经保存，不再重复爬取！
# 房屋id：103115666102 已经保存，不再重复爬取！
# 房屋id：103117102222 已经保存，不再重复爬取！
# 房屋id：103110056623 已经保存，不再重复爬取！
# 房屋id：103110175560 已经保存，不再重复爬取！
# 房屋id：103115719361 已经保存，不再重复爬取！
# https://jn.lianjia.com/ershoufang/lixia/pg27l1/
# 房屋id：103110175560 已经保存，不再重复爬取！
# 房屋id：103115945360 已经保存，不再重复爬取！
# 房屋id：103115719361 已经保存，不再重复爬取！
# 房屋id：103112505819 已经保存，不再重复爬取！
# 房屋id：103115620008 已经保存，不再重复爬取！
# 房屋id：103114292718 已经保存，不再重复爬取！
# 房屋id：103107358833 已经保存，不再重复爬取！
# 房屋id：103117116543 已经保存，不再重复爬取！
# 房屋id：103113275939 已经保存，不再重复爬取！
# 房屋id：103114083459 已经保存，不再重复爬取！
# 房屋id：103111826418 已经保存，不再重复爬取！
# 房屋id：103108400475 已经保存，不再重复爬取！
# 房屋id：103112102094 已经保存，不再重复爬取！
# 房屋id：103116695893 已经保存，不再重复爬取！
# 房屋id：103116810020 已经保存，不再重复爬取！
# 房屋id：103114285441 已经保存，不再重复爬取！
# 房屋id：103114510196 已经保存，不再重复爬取！
# 房屋id：103108204378 已经保存，不再重复爬取！
# 房屋id：103116810047 已经保存，不再重复爬取！
# 房屋id：103110159927 已经保存，不再重复爬取！
# 房屋id：103114760818 已经保存，不再重复爬取！
# 房屋id：103115724945 已经保存，不再重复爬取！
# 房屋id：103115626402 已经保存，不再重复爬取！
# 房屋id：103108438832 已经保存，不再重复爬取！
# 房屋id：103112439472 已经保存，不再重复爬取！
# 房屋id：103112973430 已经保存，不再重复爬取！
# 房屋id：103113399016 已经保存，不再重复爬取！
# 房屋id：103108204393 已经保存，不再重复爬取！
# 房屋id：103111962930 已经保存，不再重复爬取！
# 房屋id：103108694199 已经保存，不再重复爬取！
# https://jn.lianjia.com/ershoufang/lixia/pg28l1/
# 房屋id：103113116437 已经保存，不再重复爬取！
# 房屋id：103114498617 已经保存，不再重复爬取！
# 房屋id：103117421761 已经保存，不再重复爬取！
# 房屋id：103109928148 已经保存，不再重复爬取！
# 房屋id：103113399016 已经保存，不再重复爬取！
# 房屋id：103108694199 已经保存，不再重复爬取！
# 房屋id：103116226524 已经保存，不再重复爬取！
# 房屋id：103111962930 已经保存，不再重复爬取！
# 房屋id：103109435740 已经保存，不再重复爬取！
# 房屋id：103113992781 已经保存，不再重复爬取！
# 房屋id：103112003785 已经保存，不再重复爬取！
# 房屋id：103108355078 已经保存，不再重复爬取！
# 房屋id：103115785202 已经保存，不再重复爬取！
# 房屋id：103114813331 已经保存，不再重复爬取！
# 房屋id：103117491470 已经保存，不再重复爬取！
# 房屋id：103114806388 已经保存，不再重复爬取！
# 房屋id：103116964071 已经保存，不再重复爬取！
# 房屋id：103117497537 已经保存，不再重复爬取！
# 房屋id：103111347760 已经保存，不再重复爬取！
# 房屋id：103109387604 已经保存，不再重复爬取！
# 房屋id：103117404283 已经保存，不再重复爬取！
# 房屋id：103115176351 已经保存，不再重复爬取！
# 房屋id：103111249923 已经保存，不再重复爬取！
# 房屋id：103117404253 已经保存，不再重复爬取！
# 房屋id：103116900925 已经保存，不再重复爬取！
# 房屋id：103108686719 已经保存，不再重复爬取！
# 房屋id：103115946783 已经保存，不再重复爬取！
# 房屋id：103114934863 已经保存，不再重复爬取！
# 房屋id：103115144232 已经保存，不再重复爬取！
# 房屋id：103114435055 已经保存，不再重复爬取！
# https://jn.lianjia.com/ershoufang/lixia/pg29l1/
# 房屋id：103108686719 已经保存，不再重复爬取！
# 房屋id：103117404253 已经保存，不再重复爬取！
# 房屋id：103113644325 已经保存，不再重复爬取！
# 房屋id：103114934863 已经保存，不再重复爬取！
# 房屋id：103117388972 已经保存，不再重复爬取！
# 房屋id：103115946783 已经保存，不再重复爬取！
# 房屋id：103116176778 已经保存，不再重复爬取！
# 房屋id：103117031528 已经保存，不再重复爬取！
# 房屋id：103117529658 已经保存，不再重复爬取！
# 房屋id：103117395544 已经保存，不再重复爬取！
# 房屋id：103117497440 已经保存，不再重复爬取！
# 房屋id：103104885941 已经保存，不再重复爬取！
# 房屋id：103117159677 已经保存，不再重复爬取！
# 房屋id：103114346823 已经保存，不再重复爬取！
# 房屋id：103109836574 已经保存，不再重复爬取！
# 房屋id：103117184601 已经保存，不再重复爬取！
# 房屋id：103117104856 已经保存，不再重复爬取！
# 房屋id：103108378636 已经保存，不再重复爬取！
# 房屋id：103114434259 已经保存，不再重复爬取！
# 房屋id：103112761264 已经保存，不再重复爬取！
# 房屋id：103112439487 已经保存，不再重复爬取！
# 房屋id：103112389330 已经保存，不再重复爬取！
# 房屋id：103110549256 已经保存，不再重复爬取！
# 房屋id：103112853207 已经保存，不再重复爬取！
# 房屋id：103115569213 已经保存，不再重复爬取！
# 房屋id：103112592035 已经保存，不再重复爬取！
# 房屋id：103114475824 已经保存，不再重复爬取！
# 房屋id：103115058903 已经保存，不再重复爬取！
# 房屋id：103112534870 已经保存，不再重复爬取！
# 房屋id：103108758564 已经保存，不再重复爬取！
# https://jn.lianjia.com/ershoufang/lixia/pg30l1/
# 房屋id：103113886743 已经保存，不再重复爬取！
# 房屋id：103113145125 已经保存，不再重复爬取！
# 房屋id：103116659619 已经保存，不再重复爬取！
# 房屋id：103112534870 已经保存，不再重复爬取！
# 房屋id：103115058903 已经保存，不再重复爬取！
# 房屋id：103114475824 已经保存，不再重复爬取！
# 房屋id：103108758564 已经保存，不再重复爬取！
# 房屋id：103110043231 已经保存，不再重复爬取！
# 房屋id：103110647421 已经保存，不再重复爬取！
# 房屋id：103113931588 已经保存，不再重复爬取！
# 房屋id：103110150236 已经保存，不再重复爬取！
# 房屋id：103113751041 已经保存，不再重复爬取！
# 房屋id：103111618534 已经保存，不再重复爬取！
# 房屋id：103106613274 已经保存，不再重复爬取！
# 房屋id：103113406769 已经保存，不再重复爬取！
# 房屋id：103112687953 已经保存，不再重复爬取！
# 房屋id：103111852332 已经保存，不再重复爬取！
# 房屋id：103113446491 已经保存，不再重复爬取！
# 房屋id：103106515186 已经保存，不再重复爬取！
# 房屋id：103114187067 已经保存，不再重复爬取！
# 房屋id：103114713169 已经保存，不再重复爬取！
# 房屋id：103109268599 已经保存，不再重复爬取！
# 房屋id：103111134685 已经保存，不再重复爬取！
# 房屋id：103109640280 已经保存，不再重复爬取！
# 房屋id：103111397346 已经保存，不再重复爬取！
# 房屋id：103115144834 已经保存，不再重复爬取！
# 房屋id：103113105431 已经保存，不再重复爬取！
# 房屋id：103114187020 已经保存，不再重复爬取！
# 房屋id：103114308044 已经保存，不再重复爬取！
# 房屋id：103107655979 已经保存，不再重复爬取！
# https://jn.lianjia.com/ershoufang/lixia/pg31l1/
# 房屋id：103114308044 已经保存，不再重复爬取！
# 房屋id：103113105431 已经保存，不再重复爬取！
# 房屋id：103114187020 已经保存，不再重复爬取！
# 房屋id：103104363158 已经保存，不再重复爬取！
# 房屋id：103116725499 已经保存，不再重复爬取！
# 房屋id：103116630278 已经保存，不再重复爬取！
# 房屋id：103116960510 已经保存，不再重复爬取！
# 房屋id：103104962839 已经保存，不再重复爬取！
# 房屋id：103111114313 已经保存，不再重复爬取！
# 房屋id：103112937822 已经保存，不再重复爬取！
# 房屋id：103109172535 已经保存，不再重复爬取！
# 房屋id：103116375121 已经保存，不再重复爬取！
# 房屋id：103109770606 已经保存，不再重复爬取！
# 房屋id：103115518525 已经保存，不再重复爬取！
# 房屋id：103113611479 已经保存，不再重复爬取！
# 房屋id：103115258884 已经保存，不再重复爬取！
# 房屋id：103114726394 已经保存，不再重复爬取！
# 房屋id：103113960966 已经保存，不再重复爬取！
# 房屋id：103105236964 已经保存，不再重复爬取！
# 房屋id：103113770016 已经保存，不再重复爬取！
# 房屋id：103113943196 已经保存，不再重复爬取！
# 房屋id：103112717163 已经保存，不再重复爬取！
# 房屋id：103110908696 已经保存，不再重复爬取！
# 房屋id：103113739783 已经保存，不再重复爬取！
# 房屋id：103116958263 已经保存，不再重复爬取！
# 房屋id：103115624142 已经保存，不再重复爬取！
# 房屋id：103113831034 已经保存，不再重复爬取！
# 房屋id：103112127284 已经保存，不再重复爬取！
# 房屋id：103103967434 已经保存，不再重复爬取！
# 房屋id：103115739099 已经保存，不再重复爬取！
# https://jn.lianjia.com/ershoufang/lixia/pg32l1/
# 房屋id：103112777733 已经保存，不再重复爬取！
# 房屋id：103112878442 已经保存，不再重复爬取！
# 房屋id：103116536300 已经保存，不再重复爬取！
# 房屋id：103117095805 已经保存，不再重复爬取！
# 房屋id：103108658622 已经保存，不再重复爬取！
# 房屋id：103107386200 已经保存，不再重复爬取！
# 房屋id：103107866727 已经保存，不再重复爬取！
# 房屋id：103110531278 已经保存，不再重复爬取！
# 房屋id：103114601863 已经保存，不再重复爬取！
# 房屋id：103116787608 已经保存，不再重复爬取！
# 房屋id：103115251415 已经保存，不再重复爬取！
# 房屋id：103116576117 已经保存，不再重复爬取！
# 房屋id：103116116363 已经保存，不再重复爬取！
# 房屋id：103115306259 已经保存，不再重复爬取！
# 房屋id：103108009420 已经保存，不再重复爬取！
# 房屋id：103115260766 已经保存，不再重复爬取！
# 房屋id：103116400395 已经保存，不再重复爬取！
# 房屋id：103111879339 已经保存，不再重复爬取！
# 房屋id：103110135049 已经保存，不再重复爬取！
# 房屋id：103110874159 已经保存，不再重复爬取！
# 房屋id：103113505087 已经保存，不再重复爬取！
# 房屋id：103112198636 已经保存，不再重复爬取！
# 房屋id：103112919526 已经保存，不再重复爬取！
# 房屋id：103113207219 已经保存，不再重复爬取！
# 房屋id：103116180817 已经保存，不再重复爬取！
# 房屋id：103116600284 已经保存，不再重复爬取！
# 房屋id：103114533801 已经保存，不再重复爬取！
# 房屋id：103115750415 已经保存，不再重复爬取！
# 房屋id：103116978038 已经保存，不再重复爬取！
# 房屋id：103114372371 已经保存，不再重复爬取！
# https://jn.lianjia.com/ershoufang/lixia/pg33l1/
# 房屋id：103110135049 已经保存，不再重复爬取！
# 房屋id：103110874159 已经保存，不再重复爬取！
# 房屋id：103113505087 已经保存，不再重复爬取！
# 房屋id：103107452020 已经保存，不再重复爬取！
# 房屋id：103115860627 已经保存，不再重复爬取！
# 房屋id：103115260766 已经保存，不再重复爬取！
# 房屋id：103116400395 已经保存，不再重复爬取！
# 房屋id：103105545641 已经保存，不再重复爬取！
# 房屋id：103106422121 已经保存，不再重复爬取！
# 房屋id：103105596376 已经保存，不再重复爬取！
# 房屋id：103106750317 已经保存，不再重复爬取！
# 房屋id：103112883147 已经保存，不再重复爬取！
# 房屋id：103116694734 已经保存，不再重复爬取！
# 房屋id：103106862923 已经保存，不再重复爬取！
# 房屋id：103107180087 已经保存，不再重复爬取！
# 房屋id：103112198636 已经保存，不再重复爬取！
# 房屋id：103114372371 已经保存，不再重复爬取！
# 房屋id：103111023391 已经保存，不再重复爬取！
# 房屋id：103110358639 已经保存，不再重复爬取！
# 房屋id：103113338126 已经保存，不再重复爬取！
# 房屋id：103111099038 已经保存，不再重复爬取！
# 房屋id：103115660027 已经保存，不再重复爬取！
# 房屋id：103114304918 已经保存，不再重复爬取！
# 房屋id：103111870467 已经保存，不再重复爬取！
# 房屋id：103110926113 已经保存，不再重复爬取！
# 房屋id：103116125597 已经保存，不再重复爬取！
# 房屋id：103116125604 已经保存，不再重复爬取！
# 房屋id：103111658411 已经保存，不再重复爬取！
# 房屋id：103114931229 已经保存，不再重复爬取！
# 房屋id：103116234793 已经保存，不再重复爬取！
# https://jn.lianjia.com/ershoufang/lixia/pg34l1/
# 房屋id：103116234793 已经保存，不再重复爬取！
# 房屋id：103114931229 已经保存，不再重复爬取！
# 房屋id：103111497904 已经保存，不再重复爬取！
# 房屋id：103113267678 已经保存，不再重复爬取！
# 房屋id：103112951392 已经保存，不再重复爬取！
# 房屋id：103113202530 已经保存，不再重复爬取！
# 房屋id：103113206950 已经保存，不再重复爬取！
# 房屋id：103115540151 已经保存，不再重复爬取！
# 房屋id：103115306338 已经保存，不再重复爬取！
# 房屋id：103113620541 已经保存，不再重复爬取！
# 房屋id：103111289675 已经保存，不再重复爬取！
# 房屋id：103104363252 已经保存，不再重复爬取！
# 房屋id：103114153331 已经保存，不再重复爬取！
# 房屋id：103109740931 已经保存，不再重复爬取！
# 房屋id：103110976393 已经保存，不再重复爬取！
# 房屋id：103106893984 已经保存，不再重复爬取！
# 房屋id：103113139977 已经保存，不再重复爬取！
# 房屋id：103115583723 已经保存，不再重复爬取！
# 房屋id：103116360824 已经保存，不再重复爬取！
# 房屋id：103115958923 已经保存，不再重复爬取！
# 房屋id：103115668744 已经保存，不再重复爬取！
# 房屋id：103113800154 已经保存，不再重复爬取！
# 房屋id：103111320027 已经保存，不再重复爬取！
# 房屋id：103108187740 已经保存，不再重复爬取！
# 房屋id：103111248443 已经保存，不再重复爬取！
# 房屋id：103110506478 已经保存，不再重复爬取！
# 房屋id：103116533123 已经保存，不再重复爬取！
# 房屋id：103114081624 已经保存，不再重复爬取！
# 房屋id：103114783477 已经保存，不再重复爬取！
# 房屋id：103107578940 已经保存，不再重复爬取！
# https://jn.lianjia.com/ershoufang/lixia/pg35l1/
# 房屋id：103112399741 已经保存，不再重复爬取！
# 房屋id：103105697253 已经保存，不再重复爬取！
# 房屋id：103115143015 已经保存，不再重复爬取！
# 房屋id：103112592597 已经保存，不再重复爬取！
# 房屋id：103115306272 已经保存，不再重复爬取！
# 房屋id：103111320027 已经保存，不再重复爬取！
# 房屋id：103116125598 已经保存，不再重复爬取！
# 房屋id：103107365986 已经保存，不再重复爬取！
# 房屋id：103113800154 已经保存，不再重复爬取！
# 房屋id：103116305393 已经保存，不再重复爬取！
# 房屋id：103115306146 已经保存，不再重复爬取！
# 房屋id：103109255560 已经保存，不再重复爬取！
# 房屋id：103105803978 已经保存，不再重复爬取！
# 房屋id：103106687211 已经保存，不再重复爬取！
# 房屋id：103112324269 已经保存，不再重复爬取！
# 房屋id：103111562952 已经保存，不再重复爬取！
# 房屋id：103110342932 已经保存，不再重复爬取！
# 房屋id：103117338652 已经保存，不再重复爬取！
# 房屋id：103106962617 已经保存，不再重复爬取！
# 房屋id：103107201003 已经保存，不再重复爬取！
# 房屋id：103106412913 已经保存，不再重复爬取！
# 房屋id：103107401011 已经保存，不再重复爬取！
# 房屋id：103107458655 已经保存，不再重复爬取！
# 房屋id：103111396597 已经保存，不再重复爬取！
# 房屋id：103111514703 已经保存，不再重复爬取！
# 房屋id：103116083278 已经保存，不再重复爬取！
# 房屋id：103113991613 已经保存，不再重复爬取！
# 房屋id：103106112236 已经保存，不再重复爬取！
# 房屋id：103108168521 已经保存，不再重复爬取！
# 房屋id：103111604541 已经保存，不再重复爬取！
# https://jn.lianjia.com/ershoufang/lixia/pg36l1/
# 房屋id：103116125956 已经保存，不再重复爬取！
# 房屋id：103112131547 已经保存，不再重复爬取！
# 房屋id：103112497043 已经保存，不再重复爬取！
# 房屋id：103115916525 已经保存，不再重复爬取！
# 房屋id：103107201003 已经保存，不再重复爬取！
# 房屋id：103106412913 已经保存，不再重复爬取！
# 房屋id：103116034215 已经保存，不再重复爬取！
# 房屋id：103106687211 已经保存，不再重复爬取！
# 房屋id：103111215858 已经保存，不再重复爬取！
# 房屋id：103112773730 已经保存，不再重复爬取！
# 房屋id：103111432813 已经保存，不再重复爬取！
# 房屋id：103117002966 已经保存，不再重复爬取！
# 房屋id：103106962617 已经保存，不再重复爬取！
# 房屋id：103117485865 已经保存，不再重复爬取！
# 房屋id：103115037420 已经保存，不再重复爬取！
# 房屋id：103114612226 已经保存，不再重复爬取！
# 房屋id：103115340926 已经保存，不再重复爬取！
# 房屋id：103115834443 已经保存，不再重复爬取！
# 房屋id：103116420134 已经保存，不再重复爬取！
# 房屋id：103115539349 已经保存，不再重复爬取！
# 房屋id：103111046380 已经保存，不再重复爬取！
# 房屋id：103110342932 已经保存，不再重复爬取！
# 房屋id：103116083278 已经保存，不再重复爬取！
# 房屋id：103113991613 已经保存，不再重复爬取！
# 房屋id：103117410215 已经保存，不再重复爬取！
# 房屋id：103117059384 已经保存，不再重复爬取！
# 房屋id：103114470440 已经保存，不再重复爬取！
# 房屋id：103114065656 已经保存，不再重复爬取！
# 房屋id：103114545303 已经保存，不再重复爬取！
# 房屋id：103108526756 已经保存，不再重复爬取！
# https://jn.lianjia.com/ershoufang/lixia/pg37l1/
# 房屋id：103114470440 已经保存，不再重复爬取！
# 房屋id：103114065656 已经保存，不再重复爬取！
# 房屋id：103108526756 已经保存，不再重复爬取！
# 房屋id：103117064234 已经保存，不再重复爬取！
# 房屋id：103116083454 已经保存，不再重复爬取！
# 房屋id：103106936838 已经保存，不再重复爬取！
# 房屋id：103117398558 已经保存，不再重复爬取！
# 房屋id：103109923347 已经保存，不再重复爬取！
# 房屋id：103114044221 已经保存，不再重复爬取！
# 房屋id：103107458222 已经保存，不再重复爬取！
# 房屋id：103106908263 已经保存，不再重复爬取！
# 房屋id：103106658591 已经保存，不再重复爬取！
# 房屋id：103111687470 已经保存，不再重复爬取！
# 房屋id：103116827622 已经保存，不再重复爬取！
# 房屋id：103112869642 已经保存，不再重复爬取！
# 房屋id：103110364673 已经保存，不再重复爬取！
# 房屋id：103117504165 已经保存，不再重复爬取！
# 房屋id：103110708909 已经保存，不再重复爬取！
# 房屋id：103111333340 已经保存，不再重复爬取！
# 房屋id：103110491125 已经保存，不再重复爬取！
# 房屋id：103108865375 已经保存，不再重复爬取！
# 房屋id：103116192829 已经保存，不再重复爬取！
# 房屋id：103109196167 已经保存，不再重复爬取！
# 房屋id：103105163785 已经保存，不再重复爬取！
# 房屋id：103115306346 已经保存，不再重复爬取！
# 房屋id：103111006034 已经保存，不再重复爬取！
# 房屋id：103116884428 已经保存，不再重复爬取！
# 房屋id：103113932099 已经保存，不再重复爬取！
# 房屋id：103114266705 已经保存，不再重复爬取！
# 房屋id：103108091285 已经保存，不再重复爬取！
# https://jn.lianjia.com/ershoufang/lixia/pg38l1/
# 房屋id：103106957118 已经保存，不再重复爬取！
# 房屋id：103104631985 已经保存，不再重复爬取！
# 房屋id：103102818933 已经保存，不再重复爬取！
# 房屋id：103116202140 已经保存，不再重复爬取！
# 房屋id：103116190588 已经保存，不再重复爬取！
# 房屋id：103109577301 已经保存，不再重复爬取！
# 房屋id：103112960969 已经保存，不再重复爬取！
# 房屋id：103117412319 已经保存，不再重复爬取！
# 房屋id：103111112639 已经保存，不再重复爬取！
# 房屋id：103110135732 已经保存，不再重复爬取！
# 房屋id：103112566430 已经保存，不再重复爬取！
# 房屋id：103113719638 已经保存，不再重复爬取！
# 房屋id：103102437946 已经保存，不再重复爬取！
# 房屋id：103111668059 已经保存，不再重复爬取！
# 房屋id：103105554596 已经保存，不再重复爬取！
# 房屋id：103107643743 已经保存，不再重复爬取！
# 房屋id：103114376388 已经保存，不再重复爬取！
# 房屋id：103113650650 已经保存，不再重复爬取！
# 房屋id：103108801672 已经保存，不再重复爬取！
# 房屋id：103103474143 已经保存，不再重复爬取！
# 房屋id：103110660063 已经保存，不再重复爬取！
# 房屋id：103114259267 已经保存，不再重复爬取！
# 房屋id：103111140083 已经保存，不再重复爬取！
# 房屋id：103114425356 已经保存，不再重复爬取！
# 房屋id：103112793720 已经保存，不再重复爬取！
# 房屋id：103117012367 已经保存，不再重复爬取！
# 房屋id：103115107474 已经保存，不再重复爬取！
# 房屋id：103114914911 已经保存，不再重复爬取！
# 房屋id：103111700475 已经保存，不再重复爬取！
# 房屋id：103116245633 已经保存，不再重复爬取！
# https://jn.lianjia.com/ershoufang/lixia/pg39l1/
# 房屋id：103116234284 已经保存，不再重复爬取！
# 房屋id：103117171644 已经保存，不再重复爬取！
# 房屋id：103114755471 已经保存，不再重复爬取！
# 房屋id：103116919643 已经保存，不再重复爬取！
# 房屋id：103112568285 已经保存，不再重复爬取！
# 房屋id：103117012367 已经保存，不再重复爬取！
# 房屋id：103111700475 已经保存，不再重复爬取！
# 房屋id：103112901551 已经保存，不再重复爬取！
# 房屋id：103112890615 已经保存，不再重复爬取！
# 房屋id：103114726319 已经保存，不再重复爬取！
# 房屋id：103113988480 已经保存，不再重复爬取！
# 房屋id：103111786555 已经保存，不再重复爬取！
# 房屋id：103116024473 已经保存，不再重复爬取！
# 房屋id：103117386610 已经保存，不再重复爬取！
# 房屋id：103117923066 已经保存，不再重复爬取！
# 房屋id：103102332560 已经保存，不再重复爬取！
# 房屋id：103117938309 已经保存，不再重复爬取！
# 房屋id：103111958099 已经保存，不再重复爬取！
# 房屋id：103116089366 已经保存，不再重复爬取！
# 房屋id：103115778767 已经保存，不再重复爬取！
# 房屋id：103115902558 已经保存，不再重复爬取！
# 房屋id：103114173826 已经保存，不再重复爬取！
# 房屋id：103114589843 已经保存，不再重复爬取！
# 房屋id：103113196135 已经保存，不再重复爬取！
# 房屋id：103115984326 已经保存，不再重复爬取！
# 房屋id：103117172203 已经保存，不再重复爬取！
# 房屋id：103113473956 已经保存，不再重复爬取！
# 房屋id：103110680421 已经保存，不再重复爬取！
# 房屋id：103113228362 已经保存，不再重复爬取！
# 房屋id：103117082808 已经保存，不再重复爬取！
# https://jn.lianjia.com/ershoufang/lixia/pg40l1/
# 房屋id：103107458795 已经保存，不再重复爬取！
# 房屋id：103114187535 已经保存，不再重复爬取！
# 房屋id：103110680421 已经保存，不再重复爬取！
# 房屋id：103111992727 已经保存，不再重复爬取！
# 房屋id：103109612763 已经保存，不再重复爬取！
# 房屋id：103112759752 已经保存，不再重复爬取！
# 房屋id：103106596213 已经保存，不再重复爬取！
# 房屋id：103113503020 已经保存，不再重复爬取！
# 房屋id：103114793880 已经保存，不再重复爬取！
# 房屋id：103115051521 已经保存，不再重复爬取！
# 房屋id：103108777362 已经保存，不再重复爬取！
# 房屋id：103111274617 已经保存，不再重复爬取！
# 房屋id：103114759672 已经保存，不再重复爬取！
# 房屋id：103116787147 已经保存，不再重复爬取！
# 房屋id：103114741667 已经保存，不再重复爬取！
# 房屋id：103116646345 已经保存，不再重复爬取！
# 房屋id：103112926054 已经保存，不再重复爬取！
# 房屋id：103115828619 已经保存，不再重复爬取！
# 房屋id：103112087520 已经保存，不再重复爬取！
# 房屋id：103113685020 已经保存，不再重复爬取！
# 房屋id：103116125590 已经保存，不再重复爬取！
# 房屋id：103110888376 已经保存，不再重复爬取！
# 房屋id：103113519097 已经保存，不再重复爬取！
# 房屋id：103115576291 已经保存，不再重复爬取！
# 房屋id：103109243019 已经保存，不再重复爬取！
# 房屋id：103116506221 已经保存，不再重复爬取！
# 房屋id：103111800056 已经保存，不再重复爬取！
# 房屋id：103113719755 已经保存，不再重复爬取！
# 房屋id：103111022554 已经保存，不再重复爬取！
# 房屋id：103111587434 已经保存，不再重复爬取！
# https://jn.lianjia.com/ershoufang/lixia/pg41l1/
# 房屋id：103116125591 已经保存，不再重复爬取！
# 房屋id：103111022554 已经保存，不再重复爬取！
# 房屋id：103111587434 已经保存，不再重复爬取！
# 房屋id：103115594075 已经保存，不再重复爬取！
# 房屋id：103112140172 已经保存，不再重复爬取！
# 房屋id：103115430814 已经保存，不再重复爬取！
# 房屋id：103111201871 已经保存，不再重复爬取！
# 房屋id：103117055084 已经保存，不再重复爬取！
# 房屋id：103107458857 已经保存，不再重复爬取！
# 房屋id：103111338497 已经保存，不再重复爬取！
# 房屋id：103109857956 已经保存，不再重复爬取！
# 房屋id：103109882538 已经保存，不再重复爬取！
# 房屋id：103113500001 已经保存，不再重复爬取！
# 房屋id：103116094514 已经保存，不再重复爬取！
# 房屋id：103115121613 已经保存，不再重复爬取！
# 房屋id：103113302689 已经保存，不再重复爬取！
# 房屋id：103115333879 已经保存，不再重复爬取！
# 房屋id：103116125588 已经保存，不再重复爬取！
# 房屋id：103113003286 已经保存，不再重复爬取！
# 房屋id：103114557172 已经保存，不再重复爬取！
# 房屋id：103109490756 已经保存，不再重复爬取！
# 房屋id：103115962509 已经保存，不再重复爬取！
# 房屋id：103111265890 已经保存，不再重复爬取！
# 房屋id：103106101537 已经保存，不再重复爬取！
# 房屋id：103116308037 已经保存，不再重复爬取！
# 房屋id：103111043476 已经保存，不再重复爬取！
# 房屋id：103111043429 已经保存，不再重复爬取！
# 房屋id：103110571513 已经保存，不再重复爬取！
# 房屋id：103113586771 已经保存，不再重复爬取！
# 房屋id：103111813029 已经保存，不再重复爬取！
# https://jn.lianjia.com/ershoufang/lixia/pg42l1/
# 房屋id：103111043476 已经保存，不再重复爬取！
# 房屋id：103108989786 已经保存，不再重复爬取！
# 房屋id：103114565806 已经保存，不再重复爬取！
# 房屋id：103112709673 已经保存，不再重复爬取！
# 房屋id：103106101537 已经保存，不再重复爬取！
# 房屋id：103111813029 已经保存，不再重复爬取！
# 房屋id：103110571513 已经保存，不再重复爬取！
# 房屋id：103108907219 已经保存，不再重复爬取！
# 房屋id：103116713367 已经保存，不再重复爬取！
# 房屋id：103116613238 已经保存，不再重复爬取！
# 房屋id：103111200439 已经保存，不再重复爬取！
# 房屋id：103113586771 已经保存，不再重复爬取！
# 房屋id：103113662634 已经保存，不再重复爬取！
# 房屋id：103116015738 已经保存，不再重复爬取！
# 房屋id：103111075271 已经保存，不再重复爬取！
# 房屋id：103110936021 已经保存，不再重复爬取！
# 房屋id：103115556615 已经保存，不再重复爬取！
# 房屋id：103111656550 已经保存，不再重复爬取！
# 房屋id：103112101172 已经保存，不再重复爬取！
# 房屋id：103113436676 已经保存，不再重复爬取！
# 房屋id：103112850137 已经保存，不再重复爬取！
# 房屋id：103113347710 已经保存，不再重复爬取！
# 房屋id：103113500086 已经保存，不再重复爬取！
# 房屋id：103113465016 已经保存，不再重复爬取！
# 房屋id：103109904755 已经保存，不再重复爬取！
# 房屋id：103107812657 已经保存，不再重复爬取！
# 房屋id：103113667491 已经保存，不再重复爬取！
# 房屋id：103117229238 已经保存，不再重复爬取！
# 房屋id：103116559473 已经保存，不再重复爬取！
# 房屋id：103114730464 已经保存，不再重复爬取！
# https://jn.lianjia.com/ershoufang/lixia/pg43l1/
# 房屋id：103114807209 已经保存，不再重复爬取！
# 房屋id：103111464607 已经保存，不再重复爬取！
# 房屋id：103111980085 已经保存，不再重复爬取！
# 房屋id：103116694208 已经保存，不再重复爬取！
# 房屋id：103108975236 已经保存，不再重复爬取！
# 房屋id：103113367706 已经保存，不再重复爬取！
# 房屋id：103113603763 已经保存，不再重复爬取！
# 房屋id：103109151986 已经保存，不再重复爬取！
# 房屋id：103116709980 已经保存，不再重复爬取！
# 房屋id：103112072569 已经保存，不再重复爬取！
# 房屋id：103113916625 已经保存，不再重复爬取！
# 房屋id：103113544961 已经保存，不再重复爬取！
# 房屋id：103116770119 已经保存，不再重复爬取！
# 房屋id：103109747064 已经保存，不再重复爬取！
# 房屋id：103112772590 已经保存，不再重复爬取！
# 房屋id：103115407883 已经保存，不再重复爬取！
# 房屋id：103114120936 已经保存，不再重复爬取！
# 房屋id：103114395382 已经保存，不再重复爬取！
# 房屋id：103115306254 已经保存，不再重复爬取！
# 房屋id：103116963647 已经保存，不再重复爬取！
# 房屋id：103116987667 已经保存，不再重复爬取！
# 房屋id：103116184656 已经保存，不再重复爬取！
# 房屋id：103113425556 已经保存，不再重复爬取！
# 房屋id：103113313554 已经保存，不再重复爬取！
# 房屋id：103105690991 已经保存，不再重复爬取！
# 房屋id：103109062704 已经保存，不再重复爬取！
# 房屋id：103110294488 已经保存，不再重复爬取！
# 房屋id：103116942504 已经保存，不再重复爬取！
# 房屋id：103117176656 已经保存，不再重复爬取！
# 房屋id：103109206105 已经保存，不再重复爬取！
# https://jn.lianjia.com/ershoufang/lixia/pg44l1/
# 房屋id：103109349389 已经保存，不再重复爬取！
# 房屋id：103116430140 已经保存，不再重复爬取！
# 房屋id：103115279271 已经保存，不再重复爬取！
# 房屋id：103114006175 已经保存，不再重复爬取！
# 房屋id：103116531960 已经保存，不再重复爬取！
# 房屋id：103112772590 已经保存，不再重复爬取！
# 房屋id：103115306254 已经保存，不再重复爬取！
# 房屋id：103116184656 已经保存，不再重复爬取！
# 房屋id：103116987667 已经保存，不再重复爬取！
# 房屋id：103114120936 已经保存，不再重复爬取！
# 房屋id：103114395382 已经保存，不再重复爬取！
# 房屋id：103115407883 已经保存，不再重复爬取！
# 房屋id：103116963647 已经保存，不再重复爬取！
# 房屋id：103117334072 已经保存，不再重复爬取！
# 房屋id：103112432628 已经保存，不再重复爬取！
# 房屋id：103110294488 已经保存，不再重复爬取！
# 房屋id：103117099721 已经保存，不再重复爬取！
# 房屋id：103110318961 已经保存，不再重复爬取！
# 房屋id：103106683908 已经保存，不再重复爬取！
# 房屋id：103116719413 已经保存，不再重复爬取！
# 房屋id：103109548377 已经保存，不再重复爬取！
# 房屋id：103117176656 已经保存，不再重复爬取！
# 房屋id：103109206105 已经保存，不再重复爬取！
# 房屋id：103113313535 已经保存，不再重复爬取！
# 房屋id：103115982497 已经保存，不再重复爬取！
# 房屋id：103111802770 已经保存，不再重复爬取！
# 房屋id：103115590952 已经保存，不再重复爬取！
# 房屋id：103108719083 已经保存，不再重复爬取！
# 房屋id：103116574843 已经保存，不再重复爬取！
# 房屋id：103113171500 已经保存，不再重复爬取！
# https://jn.lianjia.com/ershoufang/lixia/pg45l1/
# 房屋id：103114006175 已经保存，不再重复爬取！
# 房屋id：103117322453 已经保存，不再重复爬取！
# 房屋id：103115279271 已经保存，不再重复爬取！
# 房屋id：103112403879 已经保存，不再重复爬取！
# 房屋id：103110458606 已经保存，不再重复爬取！
# 房屋id：103105082264 已经保存，不再重复爬取！
# 房屋id：103115544183 已经保存，不再重复爬取！
# 房屋id：103117185199 已经保存，不再重复爬取！
# 房屋id：103110855034 已经保存，不再重复爬取！
# 房屋id：103112141463 已经保存，不再重复爬取！
# 房屋id：103107323744 已经保存，不再重复爬取！
# 房屋id：103115556800 已经保存，不再重复爬取！
# 房屋id：103108392968 已经保存，不再重复爬取！
# 房屋id：103105713516 已经保存，不再重复爬取！
# 房屋id：103115120956 已经保存，不再重复爬取！
# 房屋id：103111055387 已经保存，不再重复爬取！
# 房屋id：103113061228 已经保存，不再重复爬取！
# 房屋id：103109882927 已经保存，不再重复爬取！
# 房屋id：103115923606 已经保存，不再重复爬取！
# 房屋id：103112884909 已经保存，不再重复爬取！
# 房屋id：103112088355 已经保存，不再重复爬取！
# 房屋id：103115619715 已经保存，不再重复爬取！
# 房屋id：103110265540 已经保存，不再重复爬取！
# 房屋id：103109834168 已经保存，不再重复爬取！
# 房屋id：103117214988 已经保存，不再重复爬取！
# 房屋id：103117129357 已经保存，不再重复爬取！
# 房屋id：103115100989 已经保存，不再重复爬取！
# 房屋id：103110012306 已经保存，不再重复爬取！
# 房屋id：103111009612 已经保存，不再重复爬取！
# 房屋id：103117099424 已经保存，不再重复爬取！
# https://jn.lianjia.com/ershoufang/lixia/pg46l1/
# 房屋id：103112088355 已经保存，不再重复爬取！
# 房屋id：103113061228 已经保存，不再重复爬取！
# 房屋id：103113459932 已经保存，不再重复爬取！
# 房屋id：103112132537 已经保存，不再重复爬取！
# 房屋id：103112095831 已经保存，不再重复爬取！
# 房屋id：103112952593 已经保存，不再重复爬取！
# 房屋id：103108188014 已经保存，不再重复爬取！
# 房屋id：103110783787 已经保存，不再重复爬取！
# 房屋id：103110855034 已经保存，不再重复爬取！
# 房屋id：103115100989 已经保存，不再重复爬取！
# 房屋id：103117153033 已经保存，不再重复爬取！
# 房屋id：103117389196 已经保存，不再重复爬取！
# 房屋id：103110012306 已经保存，不再重复爬取！
# 房屋id：103111009612 已经保存，不再重复爬取！
# 房屋id：103113370070 已经保存，不再重复爬取！
# 房屋id：103115556800 已经保存，不再重复爬取！
# 房屋id：103107323744 已经保存，不再重复爬取！
# 房屋id：103112141463 已经保存，不再重复爬取！
# 房屋id：103115923606 已经保存，不再重复爬取！
# 房屋id：103109882927 已经保存，不再重复爬取！
# 房屋id：103111055387 已经保存，不再重复爬取！
# 房屋id：103114472698 已经保存，不再重复爬取！
# 房屋id：103113297244 已经保存，不再重复爬取！
# 房屋id：103111571821 已经保存，不再重复爬取！
# 房屋id：103111430279 已经保存，不再重复爬取！
# 房屋id：103111450616 已经保存，不再重复爬取！
# 房屋id：103117088370 已经保存，不再重复爬取！
# 房屋id：103117035448 已经保存，不再重复爬取！
# 房屋id：103116739266 已经保存，不再重复爬取！
# 房屋id：103104677881 已经保存，不再重复爬取！
# https://jn.lianjia.com/ershoufang/lixia/pg47l1/
# 房屋id：103105003588 已经保存，不再重复爬取！
# 房屋id：103111470588 已经保存，不再重复爬取！
# 房屋id：103110097705 已经保存，不再重复爬取！
# 房屋id：103104677881 已经保存，不再重复爬取！
# 房屋id：103117417188 已经保存，不再重复爬取！
# 房屋id：103108971598 已经保存，不再重复爬取！
# 房屋id：103112330635 已经保存，不再重复爬取！
# 房屋id：103114719042 已经保存，不再重复爬取！
# 房屋id：103110135631 已经保存，不再重复爬取！
# 房屋id：103112951816 已经保存，不再重复爬取！
# 房屋id：103114424849 已经保存，不再重复爬取！
# 房屋id：103117167350 已经保存，不再重复爬取！
# 房屋id：103107175530 已经保存，不再重复爬取！
# 房屋id：103110573405 已经保存，不再重复爬取！
# 房屋id：103110329449 已经保存，不再重复爬取！
# 房屋id：103116681386 已经保存，不再重复爬取！
# 房屋id：103115783869 已经保存，不再重复爬取！
# 房屋id：103114316503 已经保存，不再重复爬取！
# 房屋id：103114649083 已经保存，不再重复爬取！
# 房屋id：103115081533 已经保存，不再重复爬取！
# 房屋id：103116034331 已经保存，不再重复爬取！
# 房屋id：103116708316 已经保存，不再重复爬取！
# 房屋id：103114271448 已经保存，不再重复爬取！
# 房屋id：103114718704 已经保存，不再重复爬取！
# 房屋id：103117486987 已经保存，不再重复爬取！
# 房屋id：103104943567 已经保存，不再重复爬取！
# 房屋id：103116984570 已经保存，不再重复爬取！
# 房屋id：103106775160 已经保存，不再重复爬取！
# 房屋id：103116096716 已经保存，不再重复爬取！
# 房屋id：103117016447 已经保存，不再重复爬取！
# https://jn.lianjia.com/ershoufang/lixia/pg48l1/
# 房屋id：103113991755 已经保存，不再重复爬取！
# 房屋id：103115081318 已经保存，不再重复爬取！
# 房屋id：103114631620 已经保存，不再重复爬取！
# 房屋id：103104943567 已经保存，不再重复爬取！
# 房屋id：103105003588 已经保存，不再重复爬取！
# 房屋id：103114424849 已经保存，不再重复爬取！
# 房屋id：103112951816 已经保存，不再重复爬取！
# 房屋id：103106775160 已经保存，不再重复爬取！
# 房屋id：103116984570 已经保存，不再重复爬取！
# 房屋id：103108971598 已经保存，不再重复爬取！
# 房屋id：103116708316 已经保存，不再重复爬取！
# 房屋id：103116034331 已经保存，不再重复爬取！
# 房屋id：103110135631 已经保存，不再重复爬取！
# 房屋id：103117167350 已经保存，不再重复爬取！
# 房屋id：103111470588 已经保存，不再重复爬取！
# 房屋id：103114718704 已经保存，不再重复爬取！
# 房屋id：103117486987 已经保存，不再重复爬取！
# 房屋id：103104677881 已经保存，不再重复爬取！
# 房屋id：103110573405 已经保存，不再重复爬取！
# 房屋id：103110329449 已经保存，不再重复爬取！
# 房屋id：103116096716 已经保存，不再重复爬取！
# 房屋id：103107174932 已经保存，不再重复爬取！
# 房屋id：103105375422 已经保存，不再重复爬取！
# 房屋id：103109445509 已经保存，不再重复爬取！
# 房屋id：103113471068 已经保存，不再重复爬取！
# 房屋id：103113146826 已经保存，不再重复爬取！
# 房屋id：103113146192 已经保存，不再重复爬取！
# 房屋id：103114239938 已经保存，不再重复爬取！
# 房屋id：103109025196 已经保存，不再重复爬取！
# 房屋id：103108874967 已经保存，不再重复爬取！
# https://jn.lianjia.com/ershoufang/lixia/pg49l1/
# 房屋id：103113991755 已经保存，不再重复爬取！
# 房屋id：103114037360 已经保存，不再重复爬取！
# 房屋id：103115525460 已经保存，不再重复爬取！
# 房屋id：103115848959 已经保存，不再重复爬取！
# 房屋id：103113735781 已经保存，不再重复爬取！
# 房屋id：103117253974 已经保存，不再重复爬取！
# 房屋id：103116197020 已经保存，不再重复爬取！
# 房屋id：103114571794 已经保存，不再重复爬取！
# 房屋id：103117152291 已经保存，不再重复爬取！
# 房屋id：103111336285 已经保存，不再重复爬取！
# 房屋id：103114933698 已经保存，不再重复爬取！
# 房屋id：103106586487 已经保存，不再重复爬取！
# 房屋id：103112693455 已经保存，不再重复爬取！
# 房屋id：103115853239 已经保存，不再重复爬取！
# 房屋id：103113212550 已经保存，不再重复爬取！
# 房屋id：103103437455 已经保存，不再重复爬取！
# 房屋id：103115236382 已经保存，不再重复爬取！
# 房屋id：103113140347 已经保存，不再重复爬取！
# 房屋id：103116625887 已经保存，不再重复爬取！
# 房屋id：103116441782 已经保存，不再重复爬取！
# 房屋id：103115179472 已经保存，不再重复爬取！
# 房屋id：103117405714 已经保存，不再重复爬取！
# 房屋id：103115933091 已经保存，不再重复爬取！
# 房屋id：103110475163 已经保存，不再重复爬取！
# 房屋id：103110258840 已经保存，不再重复爬取！
# 房屋id：103117260301 已经保存，不再重复爬取！
# 房屋id：103117065895 已经保存，不再重复爬取！
# 房屋id：103113333505 已经保存，不再重复爬取！
# 房屋id：103117304519 已经保存，不再重复爬取！
# 房屋id：103109345441 已经保存，不再重复爬取！
# https://jn.lianjia.com/ershoufang/lixia/pg50l1/
# 房屋id：103109883515 已经保存，不再重复爬取！
# 房屋id：103114120894 已经保存，不再重复爬取！
# 房屋id：103116555960 已经保存，不再重复爬取！
# 房屋id：103115716258 已经保存，不再重复爬取！
# 房屋id：103115013688 已经保存，不再重复爬取！
# 房屋id：103107458636 已经保存，不再重复爬取！
# 房屋id：103112780503 已经保存，不再重复爬取！
# https://jn.lianjia.com/ershoufang/lixia/pg50l1/ 103117981948 鲁商盛景广场
# 房屋id：103102803796 已经保存，不再重复爬取！
# 房屋id：103112082634 已经保存，不再重复爬取！
# 房屋id：103102788294 已经保存，不再重复爬取！
# 房屋id：103102788307 已经保存，不再重复爬取！
# 房屋id：103115081236 已经保存，不再重复爬取！
# 房屋id：103111146757 已经保存，不再重复爬取！
# 房屋id：103102270877 已经保存，不再重复爬取！
# 房屋id：103102780930 已经保存，不再重复爬取！
# 房屋id：103103917158 已经保存，不再重复爬取！
# https://jn.lianjia.com/ershoufang/lixia/pg50l1/ 103117897331 济南万科城
# list index out of range
# 爬取数据异常，重新尝试爬取数据。爬取地址：https://jn.lianjia.com/ershoufang/103117897331.html
# https://jn.lianjia.com/ershoufang/lixia/pg50l1/ 103117897331 济南万科城
# list index out of range
# 爬取数据异常，重新尝试爬取数据。爬取地址：https://jn.lianjia.com/ershoufang/103117897331.html
# https://jn.lianjia.com/ershoufang/lixia/pg50l1/ 103117897331 济南万科城
# list index out of range
# 爬取数据异常，重新尝试爬取数据。爬取地址：https://jn.lianjia.com/ershoufang/103117897331.html
# https://jn.lianjia.com/ershoufang/lixia/pg50l1/ 103117897331 济南万科城
# list index out of range
# 爬取数据异常，重新尝试爬取数据。爬取地址：https://jn.lianjia.com/ershoufang/103117897331.html
# https://jn.lianjia.com/ershoufang/lixia/pg50l1/ 103117897331 济南万科城
# list index out of range
# 爬取数据异常，重新尝试爬取数据。爬取地址：https://jn.lianjia.com/ershoufang/103117897331.html
# 房屋id：103112502508 已经保存，不再重复爬取！
# 房屋id：103117204361 已经保存，不再重复爬取！
# 房屋id：103113985698 已经保存，不再重复爬取！
# 房屋id：103102670956 已经保存，不再重复爬取！
# 房屋id：103103073089 已经保存，不再重复爬取！
# https://jn.lianjia.com/ershoufang/lixia/pg50l1/ 103117589191 凯旋公馆
# list index out of range
# 爬取数据异常，重新尝试爬取数据。爬取地址：https://jn.lianjia.com/ershoufang/103117589191.html
# https://jn.lianjia.com/ershoufang/lixia/pg50l1/ 103117589191 凯旋公馆
# list index out of range
# 爬取数据异常，重新尝试爬取数据。爬取地址：https://jn.lianjia.com/ershoufang/103117589191.html
# https://jn.lianjia.com/ershoufang/lixia/pg50l1/ 103117589191 凯旋公馆
# list index out of range
# 爬取数据异常，重新尝试爬取数据。爬取地址：https://jn.lianjia.com/ershoufang/103117589191.html
# https://jn.lianjia.com/ershoufang/lixia/pg50l1/ 103117589191 凯旋公馆
# list index out of range
# 爬取数据异常，重新尝试爬取数据。爬取地址：https://jn.lianjia.com/ershoufang/103117589191.html
# https://jn.lianjia.com/ershoufang/lixia/pg50l1/ 103117589191 凯旋公馆
# list index out of range
# 爬取数据异常，重新尝试爬取数据。爬取地址：https://jn.lianjia.com/ershoufang/103117589191.html
# 房屋id：103103187515 已经保存，不再重复爬取！
# 房屋id：103102349222 已经保存，不再重复爬取！
# 房屋id：103110619550 已经保存，不再重复爬取！
# 房屋id：103102636365 已经保存，不再重复爬取！
# 房屋id：103114872952 已经保存，不再重复爬取！
# 房屋id：103109869460 已经保存，不再重复爬取！
# https://jn.lianjia.com/ershoufang/lixia/pg51l1/
# 房屋id：103117590211 已经保存，不再重复爬取！
# 房屋id：103110061853 已经保存，不再重复爬取！
# 房屋id：103113523036 已经保存，不再重复爬取！
# 房屋id：103117924686 已经保存，不再重复爬取！
# https://jn.lianjia.com/ershoufang/lixia/pg51l1/ 103117749693 保利华庭
# list index out of range
# 爬取数据异常，重新尝试爬取数据。爬取地址：https://jn.lianjia.com/ershoufang/103117749693.html
# https://jn.lianjia.com/ershoufang/lixia/pg51l1/ 103117749693 保利华庭
# list index out of range
# 爬取数据异常，重新尝试爬取数据。爬取地址：https://jn.lianjia.com/ershoufang/103117749693.html
# https://jn.lianjia.com/ershoufang/lixia/pg51l1/ 103117749693 保利华庭
# list index out of range
# 爬取数据异常，重新尝试爬取数据。爬取地址：https://jn.lianjia.com/ershoufang/103117749693.html
# https://jn.lianjia.com/ershoufang/lixia/pg51l1/ 103117749693 保利华庭
# list index out of range
# 爬取数据异常，重新尝试爬取数据。爬取地址：https://jn.lianjia.com/ershoufang/103117749693.html
# https://jn.lianjia.com/ershoufang/lixia/pg51l1/ 103117749693 保利华庭
# list index out of range
# 爬取数据异常，重新尝试爬取数据。爬取地址：https://jn.lianjia.com/ershoufang/103117749693.html
# 房屋id：103117917341 已经保存，不再重复爬取！
# https://jn.lianjia.com/ershoufang/lixia/pg51l1/ 103110484733 济南万科城
# list index out of range
# 爬取数据异常，重新尝试爬取数据。爬取地址：https://jn.lianjia.com/ershoufang/103110484733.html
